# %% [markdown]
# # Portfolios

# %%
import numpy as np
import pandas as pd
import mpt.data as data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 60-40 SPY-AGG

# %%
#t = ["AGG", "BIL", "EEM", "GLD", "SPY"]
#t = ["SPY", "AGG", "GLD"]
#t = ["AAPL", "GOOG", "MSFT", "NVDA"]
t= ['ISF.L', 'IUKD.L', 'SLXX.L', 'ISXF.L', 'IGLT.L']

# %%
f=data.Frequency.D
y=2
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df = df[['Close']].pct_change().rename(columns={'Close':'Return'})

# %%
df
# Out:
# Price         Return
# Ticker         ISF.L    ISXF.L    IUKD.L    SLXX.L
# Date
# 2022-11-14       NaN       NaN       NaN       NaN
# 2022-11-15 -0.001661  0.005979 -0.008730  0.008431
# 2022-11-16 -0.002495  0.010592 -0.004940  0.008115
# 2022-11-17  0.000556 -0.005027  0.000288 -0.005000
# 2022-11-18  0.004723 -0.003241  0.013811 -0.001103
# ...              ...       ...       ...       ...
# 2024-11-07 -0.001385  0.003066 -0.002020  0.005516
# 2024-11-08 -0.008321  0.004463 -0.009445  0.004826
# 2024-11-11  0.006738  0.002560  0.005994 -0.000246
# 2024-11-12 -0.012375 -0.003420 -0.015572 -0.002956
# 2024-11-14  0.006009  0.000048  0.007703  0.001194
#
# [506 rows x 4 columns]

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# Ticker
# ISF.L            0.043861        0.106818 -0.549647  5.616062
# ISXF.L           0.035833        0.070516  0.584284  5.826784
# IUKD.L           0.020263        0.128454 -0.215559  4.720639
# SLXX.L           0.045635        0.068460  0.476632  5.449848
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# Ticker
# ISF.L                  0.011533            0.015893      0.466646
# ISXF.L                 0.006137            0.008753      0.544652
# IUKD.L                 0.013405            0.018212      0.223619
# SLXX.L                 0.006091            0.008529      0.702374
#
#         Max Drawdown
# Ticker
# ISF.L      -0.095217
# ISXF.L     -0.093972
# IUKD.L     -0.168499
# SLXX.L     -0.089219

# %%
ts.plot()

# %%
ts.plot_corr()

# %%
ts.plot_ef()

# %%
ts.plot_w()
# Out:
#           EW           GMV           MSR
# Ticker
# ISF.L   0.25  2.292811e-01  2.198041e-01
# ISXF.L  0.25  2.095902e-01  1.991593e-14
# IUKD.L  0.25  5.478129e-11  3.520058e-14
# SLXX.L  0.25  5.611287e-01  7.801959e-01
