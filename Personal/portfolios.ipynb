# %% [markdown]
# # Portfolios

# %%
import numpy as np
import pandas as pd
import mpt.data as data

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 60-40 SPY-AGG

# %%
#t = ["AGG", "BIL", "EEM", "GLD", "SPY"]
#t = ["SPY", "AGG", "GLD"]
t = ["AAPL", "GOOG", "MSFT", "NVDA"]

# %%
f=data.Frequency.D
y=5
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df = df[['Close']].pct_change().rename(columns={'Close':'Return'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = df[['Close']].pct_change().rename(columns={'Close':'Return'})
#
# File c:\Users\jlche\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\jlche\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:2648, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2645 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2646     indexer = self._get_indexer_level_0(keyarr)
# -> 2648     self._raise_if_missing(key, indexer, axis_name)
#    2649     return self[indexer], indexer
#    2651 return super()._get_indexer_strict(key, axis_name)
#
# File c:\Users\jlche\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:2666, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2664 cmask = check == -1
#    2665 if cmask.any():
# -> 2666     raise KeyError(f"{keyarr[cmask]} not in index")
#    2667 # We get here when levels still contain values which are not
#    2668 # actually in Index anymore
#    2669 raise KeyError(f"{keyarr} not in index")
#
# KeyError: "['Close'] not in index"

# %%
df
# Out:
# Price            Close                                     Dividends       \
# Ticker            AAPL        GOOG        MSFT        NVDA      AAPL GOOG
# Date
# 2019-10-21   58.182003   62.154858  132.221359    4.876532       0.0  0.0
# 2019-10-22   58.048969   61.987770  130.253769    4.866578       0.0  0.0
# 2019-10-23   58.827911   62.802273  131.084763    4.853643       0.0  0.0
# 2019-10-24   58.924690   62.895042  133.663681    4.897677       0.0  0.0
# 2019-10-25   59.650421   63.101532  134.418213    5.088748       0.0  0.0
# ...                ...         ...         ...         ...       ...  ...
# 2024-10-15  233.850006  166.899994  418.739990  131.600006       0.0  0.0
# 2024-10-16  231.779999  166.740005  416.119995  135.720001       0.0  0.0
# 2024-10-17  232.149994  164.509995  416.720001  136.929993       0.0  0.0
# 2024-10-18  235.000000  165.050003  418.160004  138.000000       0.0  0.0
# 2024-10-21  236.429993  165.324997  415.040009  141.419998       0.0  0.0
#
# Price                       High              ... Stock Splits         Volume  \
# Ticker     MSFT NVDA        AAPL        GOOG  ...         MSFT NVDA      AAPL
# Date                                          ...
# 2019-10-21  0.0  0.0   58.298123   62.577769  ...          0.0  0.0  87247200
# 2019-10-22  0.0  0.0   58.590848   62.376814  ...          0.0  0.0  82293600
# 2019-10-23  0.0  0.0   58.842429   62.840178  ...          0.0  0.0  75828800
# 2019-10-24  0.0  0.0   59.219822   63.045175  ...          0.0  0.0  69275200
# 2019-10-25  0.0  0.0   59.686706   63.324484  ...          0.0  0.0  73477200
# ...         ...  ...         ...         ...  ...          ...  ...       ...
# 2024-10-15  0.0  0.0  237.490005  169.089996  ...          0.0  0.0  64751400
# 2024-10-16  0.0  0.0  232.119995  167.279999  ...          0.0  0.0  34082200
# 2024-10-17  0.0  0.0  233.850006  167.929993  ...          0.0  0.0  32993800
# 2024-10-18  0.0  0.0  236.179993  166.369995  ...          0.0  0.0  46416300
# 2024-10-21  0.0  0.0  236.580002  166.220001  ...          0.0  0.0  15749164
#
# Price                                        Return                      \
# Ticker          GOOG      MSFT       NVDA      AAPL      GOOG      MSFT
# Date
# 2019-10-21  20544000  20078200  261868000       NaN       NaN       NaN
# 2019-10-22  20476000  27431000  328720000 -0.002287 -0.002688 -0.014881
# 2019-10-23  18230000  29844600  279916000  0.013419  0.013140  0.006380
# 2019-10-24  20562000  37029300  232020000  0.001645  0.001477  0.019674
# 2019-10-25  24262000  25959700  423092000  0.012316  0.003283  0.005645
# ...              ...       ...        ...       ...       ...       ...
# 2024-10-15  14829300  18900200  377831000  0.011025  0.003306 -0.000954
# 2024-10-16   9968500  15508900  264879700 -0.008852 -0.000959 -0.006257
# 2024-10-17  15113400  14820000  306435900  0.001596 -0.013374  0.001442
# 2024-10-18  13086900  17138600  175800600  0.012277  0.003283  0.003456
# 2024-10-21   4305326   5107498  131091178  0.006085  0.001666 -0.007461
#
# Price
# Ticker          NVDA
# Date
# 2019-10-21       NaN
# 2019-10-22 -0.002041
# 2019-10-23 -0.002658
# 2019-10-24  0.009072
# 2019-10-25  0.039013
# ...              ...
# 2024-10-15 -0.046860
# 2024-10-16  0.031307
# 2024-10-17  0.008915
# 2024-10-18  0.007814
# 2024-10-21  0.024783
#
# [1259 rows x 32 columns]

# %%
ts.plot_corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ts.plot_corr()
#
# File c:\Users\jlche\OneDrive\GitHub\Finance\Personal\mpt\data.py:122, in MultiTimeSeries.plot_corr(self)
#     118 def plot_corr(self):
#     119     '''
#     120     Plot correlaion heatmap
#     121     '''
# --> 122     df = self.data[['Return']].dropna().droplevel(0, axis=1)
#     123     corr= df.corr()
#     124     sns.heatmap(corr, annot=True, fmt='.2f')
#
# File c:\Users\jlche\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\jlche\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:2648, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2645 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2646     indexer = self._get_indexer_level_0(keyarr)
# -> 2648     self._raise_if_missing(key, indexer, axis_name)
#    2649     return self[indexer], indexer
#    2651 return super()._get_indexer_strict(key, axis_name)
#
# File c:\Users\jlche\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:2666, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2664 cmask = check == -1
#    2665 if cmask.any():
# -> 2666     raise KeyError(f"{keyarr[cmask]} not in index")
#    2667 # We get here when levels still contain values which are not
#    2668 # actually in Index anymore
#    2669 raise KeyError(f"{keyarr} not in index")
#
# KeyError: "['Return'] not in index"

# %%
ts.plot_ef()

# %%
ts.plot_w()
# Out:
#         EW       GMV           MSR
# AAPL  0.25  0.300531  6.222650e-01
# GOOG  0.25  0.233585  3.252607e-19
# MSFT  0.25  0.465884  0.000000e+00
# NVDA  0.25  0.000000  3.777350e-01
