# %% [markdown]
# # Compare ETFs
#
# Check:
# - https://www.portfoliovisualizer.com/-
# - https://github.com/PanPip/quantstats

# %%
# %pip install --upgrade numpy
# %pip install --upgrade pandas
# %pip install --upgrade matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import mpt.data as data

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Risk-Free Rate
#
# For currency USD, it would make sense to use:
# - ^IRX - [13 Week Treasury Bill](https://www.cboe.com/us/indices/dashboard/irx/)
# - BIL - [SPDR Bloomberg 1-3 Month T-Bill ETF Dist](https://www.ssga.com/us/en/individual/etfs/funds/spdr-bloomberg-1-3-month-t-bill-etf-bil)
# - TBIL - [US Treasury 3 Month Bill ETF](https://www.ustreasuryetf.com/etf/tbil/)
#
# For currency EUR, the following are two good candidates, but considering negative returns, cash (zero return, do nothing) is better
# - EXVM.DE - [iShares eb.rexx® Government Germany 0-1yr UCITS ETF Dist](https://www.blackrock.com/fr/intermediaries/products/251779/ishares-ebrexx-government-germany-0-1yr-ucits-etf-de-fund#/)
# - PEU.PA - [Invesco Euro Cash 3 Months UCITS ETF Acc](https://etf.invesco.com/fr/private/fr/product/invesco-euro-cash-3-months-ucits-etf-acc/trading-information)

# %%
t=['EXVM.DE', 'PEU.PA']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness    Kurtosis  \
# EXVM.DE          -0.017685        0.009738 -4.268771  196.811543
# PEU.PA           -0.003754        0.006087 -1.583632  962.226788
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# EXVM.DE                -0.000785            0.001577     -1.811271
# PEU.PA                 -0.006623            0.000455     -0.613632
#
#          Max Drawdown
# EXVM.DE     -0.168917
# PEU.PA      -0.045612

# %%
ts.plot()

# %% [markdown]
# ## EUR Stock ETFs

# %% [markdown]
# ### EUR Stock Indexes
#
# #### CAC
# - CAC.PA
# - DX2G.DE
#
# #### DAX
# - DAX.PA
# - DBXD.DE
# - EXS1.DE
#
# #### STOXX® Europe 600
# - EXIE.DE/EXSA.DE - [iShares STOXX Europe 600 UCITS ETF Acc/Dist](https://www.blackrock.com/fr/particuliers/products/251931/ishares-stoxx-europe-600-ucits-etf-de-fund)
# - EXSI.DE - [iShares EURO STOXX UCITS ETF (DE)](https://www.blackrock.com/fr/intermediaries/products/251780/ishares-euro-stoxx-ucits-etf-de-fund)
# - MEUD.PA - [Lyxor Core STOXX Europe 600 (DR) - UCITS ETF Acc](https://www.amundietf.fr/fr/professionnels/produits/equity/lyxor-core-stoxx-europe-600-dr-ucits-etf-acc/lu0908500753)
#
# #### MSCI World
# - EUNL.DE - [iShares Core MSCI World UCITS ETF USD](https://www.blackrock.com/fr/intermediaries/products/251882/ishares-msci-world-ucits-etf-acc-fund)

# %%
# t=['CAC.PA', 'DX2G.DE'] # CAC
# t=['DAX.PA', 'DBXD.DE', 'EXS1.DE'] # DAX
# t = ['EXSA.DE', 'EXSI.DE', 'MEUD.PA'] # STOXX® Europe 600
# Best ETFs
t=['DBXD.DE', 'DX2G.DE', 'EUNL.DE', 'MEUD.PA']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# EXSA.DE           0.038202        0.170336 -0.914698  14.764302
# EXSI.DE           0.048683        0.184610 -0.860742  14.428533
# MEUD.PA           0.068284        0.168223 -0.658248  12.341419
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# EXSA.DE                 0.017517            0.026432      0.313971
# EXSI.DE                 0.018873            0.028285      0.362043
# MEUD.PA                 0.017011            0.026292      0.496839
#
#          Max Drawdown
# EXSA.DE     -0.358977
# EXSI.DE     -0.383311
# MEUD.PA     -0.354561

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### EUR Sectors

# %% [markdown]
# ### EUR Factors

# %% [markdown]
# ## EUR Bond ETFs

# %% [markdown]
# ### EUR Investment Grade Bonds
#
# - IBCX.L - [iShares € Corp Bond Large Cap UCITS ETF](https://www.blackrock.com/fr/intermediaries/products/251565/ishares-euro-corporate-bond-large-cap-ucits-etf)
# - IEAA.L, IEAC.L - [iShares Core € Corp Bond UCITS ETF](https://www.blackrock.com/fr/intermediaries/products/290619/ishares-core-corp-bond-ucits-etf)

# %%
t=['IBCX.L', 'IEAA.L', 'IEAC.L']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# IBCX.L          -0.023744        0.057224 -3.494201  84.980801
# IEAA.L          -0.012694        0.052164 -2.662864  66.329628
# IEAC.L          -0.022760        0.053083 -2.452200  69.123791
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# IBCX.L                 0.002808            0.008119     -0.386715
# IEAA.L                 0.003300            0.007732     -0.217412
# IEAC.L                 0.003077            0.007902     -0.402658
#
#         Max Drawdown
# IBCX.L     -0.188760
# IEAA.L     -0.172865
# IEAC.L     -0.181891

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### EUR High Yield Bonds
#
# - HIGH.L, IHYG.L - [iShares € High Yield Corp Bond UCITS ETF](https://www.blackrock.com/fr/intermediaries/products/251843/ishares-euro-high-yield-corporate-bond-ucits-etf)

# %%
t=['HIGH.L', 'IHYG.L']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# HIGH.L           0.005208        0.085586 -3.527394  62.096282
# IHYG.L          -0.028085        0.090745 -3.305653  63.788519
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# HIGH.L                 0.006549            0.012543      0.104531
# IHYG.L                 0.006685            0.013978     -0.264686
#
#         Max Drawdown
# HIGH.L     -0.254190
# IHYG.L     -0.284249

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### EUR Short Terms Bonds
#
# - ECR3.DE - [Amundi Index Euro Corporate SRI 0-3 Y UCITS ETF](https://www.amundietf.fr/fr/particuliers/produits/fixed-income/amundi-index-euro-corporate-sri-03y-ucits-etf-dr-c/lu2037748774)
# - ERNE.L, ERNX.DE - [iShares EUR Ultrashort Bond UCITS ETF](https://www.blackrock.com/fr/intermediaries/products/258114/ishares-euro-ultrashort-bond-ucits-etf)
# - SUSE.SW, IE3E.DE - [iShares € Corp Bond 0-3yr **ESG** UCITS ETF](https://www.blackrock.com/fr/intermediaries/products/280851/ishares-sustainable-euro-corporate-bond-0-3yr-ucits-etf)
# - SEUC.L - [SPDR® Bloomberg 0-3 Year Euro Corporate Bond UCITS ETF](https://www.ssga.com/fr/en_gb/institutional/etfs/funds/spdr-bloomberg-0-3-year-euro-corporate-bond-ucits-etf-dist-sybd-gy)

# %%
t=['ECR3.DE', 'ERNE.L', 'ERNX.DE', 'IE3E.DE', 'SEUC.L', 'SUSE.SW']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# ECR3.DE          -0.008904        0.016207  0.440291   9.144154
# ERNE.L            0.003155        0.005182 -0.376915  12.060425
# ERNX.DE           0.002208        0.006895  3.569266  82.183716
# IE3E.DE          -0.005695        0.017346  0.166859   9.596419
# SEUC.L           -0.011217        0.016989 -0.228249   9.226563
# SUSE.SW          -0.009776        0.015053 -0.083048   9.322572
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# ECR3.DE                 0.001456            0.002499     -0.541343
# ERNE.L                  0.000499            0.000827      0.611531
# ERNX.DE                -0.000533            0.000837      0.323760
# IE3E.DE                 0.001622            0.002704     -0.319727
# SEUC.L                  0.001738            0.002800     -0.651827
# SUSE.SW                 0.001500            0.002447     -0.641993
#
#          Max Drawdown
# ...

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ## USD Stock ETFs

# %% [markdown]
# ### USD Index ETFs
#
# #### S&P 500
# - CSPX.L - [iShares Core S&P 500 UCITS ETF](https://www.blackrock.com/fr/particuliers/products/253743/ishares-sp-500-b-ucits-etf-acc-fund)
# - VUSD.L - [Vanguard S&P 500 UCITS ETF](https://www.fr.vanguard/professionnel/produits/etf/action/9503/sp-500-ucits-etf-usd-distributing)
# - SPY5.L - [SPDR S&P 500 UCITS ETF](https://www.ssga.com/fr/en_gb/institutional/etfs/funds/spdr-sp-500-ucits-etf-dist-spy5-gy)
#
# #### Nasdaq
# - CSNDX.SW, EXXT.DE, NQSE.DE - [iShares NASDAQ 100 UCITS ETF](https://www.blackrock.com/fr/particuliers/products/253741/ishares-nasdaq-100-ucits-etf)
#
# #### Dow Jones
#
#
# #### Russel 2000
# - IWM - [iShares Russell 2000 ETF](https://www.blackrock.com/us/individual/products/239710/ishares-russell-2000-etf)
#
# #### MSCI World
# - EIMI.L, EIMU.L - [iShares Core MSCI Emerging Markets IMI UCITS ETF Acc](https://www.blackrock.com/fr/intermediaries/products/264659/ishares-msci-emerging-markets-imi-ucits-etf)
# - IWDA.L - [iShares Core MSCI World UCITS ETF USD](https://www.blackrock.com/fr/intermediaries/products/251882/ishares-msci-world-ucits-etf-acc-fund)
# - VEA - [Vanguard FTSE Developed Markets ETF](https://investor.vanguard.com/investment-products/etfs/profile/vea)

# %%
# S&P 500
# t=['CSPX.L', 'VUSD.L', 'SPY5.L']
# Nasdaq
t=['CSNDX.SW', 'EXXT.DE', 'NQSE.DE', 'SXRV.DE']
# Russel 2000
# t=['IWM']
# MSCI World
# t=['EIMI.L', 'EIMU.L', 'IWDA.L']
# Best ETFs
#t=['CSPX.L', 'IWDA.L']

f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
ts.stats()
# Out:
#           Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# CSNDX.SW           0.121341        0.237108 -0.193791  6.286423
# EXXT.DE            0.138380        0.225844 -0.321314  5.570514
# NQSE.DE            0.094873        0.237627 -0.264176  5.883483
# SXRV.DE            0.143011        0.225438 -0.330900  5.490848
#
#           Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# CSNDX.SW                 0.023824            0.034575      0.646786
# EXXT.DE                  0.023319            0.033921      0.743240
# NQSE.DE                  0.024383            0.035433      0.531507
# SXRV.DE                  0.023320            0.033880      0.765181
#
#           Max Drawdown
# CSNDX.SW     -0.351173
# EXXT.DE      -0.316488
# NQSE.DE      -0.376688
# SXRV.DE      -0.313272

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### USD Factors
#
# - IWMO [iShares Edge MSCI World Momentum Factor UCITS ETF Acc](https://www.blackrock.com/fr/intermediaries/products/270051/ishares-msci-world-momentum-factor-ucits-etf)

# %% [markdown]
# ### Cyber-security
#
# - CIBR
# - CBRS

# %%
t=['CSPX.L', 'EIMI.L', 'EIMU.L', 'IWDA.L', 'VUSD.L', 'SPY']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# CSPX.L           0.092979        0.190815 -0.464420   9.858876
# EIMI.L          -0.015266        0.212012 -0.806094  10.967910
# EIMU.L          -0.037384        0.211461 -0.876632  12.442367
# IWDA.L           0.068227        0.185821 -0.640394  12.011980
# SPY              0.094736        0.211825 -0.496106  13.819856
# VUSD.L           0.076580        0.191181 -0.514834   9.776378
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# CSPX.L                 0.019220            0.029199      0.592885
# EIMI.L                 0.022689            0.031756      0.034434
# EIMU.L                 0.022561            0.032135     -0.072919
# IWDA.L                 0.018835            0.028316      0.467798
# SPY                    0.020406            0.032651      0.565060
# VUSD.L                 0.019499            0.029438      0.504851
#
#         Max Drawdown
# CSPX.L     -0.339050
# ...

# %%
ts.plot()

# %% [markdown]
# ### Clean/Green Energy/SRI
#
# - INRA.AS, INRG.L, IQQH.DE - [iShares Global Clean Energy UCITS ETF](https://www.blackrock.com/fr/particuliers/products/251911/ishares-global-clean-energy-ucits-etf)
# - IESE.AS, ISED.AS - [iShares MSCI Europe SRI UCITS ETF Acc/Dist](https://www.blackrock.com/fr/particuliers/products/251767/ishares-dow-jones-europe-sustainability-screened-ucits-etf)
# - HYDRO.L
# - VOLT
# - BATT

# %%
t=['IESE.AS', 'ISED.AS', 'INRA.AS', 'INRG.SW', 'IQQH.DE', 'SPY']
f=data.Frequency.D
y=1
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# IESE.AS          -0.008948        0.168103  0.046661  3.289408
# INRA.AS          -0.099598        0.315671 -0.033301  3.933039
# INRG.SW          -0.104535        0.309343  0.071803  4.375214
# IQQH.DE          -0.086253        0.269811  0.111539  4.746006
# ISED.AS          -0.035010        0.170418 -0.083967  3.908922
# SPY              -0.108535        0.229983 -0.009626  3.724332
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# IESE.AS                 0.017195            0.022363      0.030644
# INRA.AS                 0.032740            0.044033     -0.169551
# INRG.SW                 0.031361            0.043231     -0.195998
# IQQH.DE                 0.027029            0.038038     -0.194160
# ISED.AS                 0.017800            0.023162     -0.122529
# SPY                     0.024009            0.033201     -0.367923
#
#          Max Drawdown
# IESE.AS     -0.171826
# ...

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### Healthcare
#
# - CBUF
# - IUHC
# - QDVG
# - STW
# - XDWH

# %%
t=['CBUF.DE', 'IUHC.L', 'QDVG.DE', 'XDWH.L', 'SPY']
f=data.Frequency.D
y=3
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# CBUF.DE           0.164526        0.157698  0.270052  5.186952
# IUHC.L            0.200167        0.180455  0.200573  4.781114
# QDVG.DE           0.199349        0.170927  0.269187  4.600148
# SPY               0.225094        0.208224  0.353277  7.770441
# XDWH.L            0.169724        0.168589  0.304508  5.189104
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# CBUF.DE                 0.014472            0.020276      1.135426
# IUHC.L                  0.016844            0.023858      1.218107
# QDVG.DE                 0.015745            0.021739      1.269198
# SPY                     0.018073            0.028993      1.209410
# XDWH.L                  0.015383            0.022268      1.105715
#
#          Max Drawdown
# CBUF.DE     -0.145053
# IUHC.L      -0.164407
# QDVG.DE     -0.134513
# SPY         -0.244964
# XDWH.L      -0.172067

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### Semiconductors
#
# - SEME.PA - [iShares MSCI Global Semiconductors UCITS ETF USD Acc](https://www.blackrock.com/fr/intermediaries/products/319084/ishares-msci-global-semiconductors-ucits-etf)
# - SMH.L, VVSM.DE - [VanEck Semiconductor UCITS ETF](https://www.vaneck.com/fr/en/smh/)

# %%
t=['SEME.PA', 'SMH.L', 'VVSM.DE', 'NVDA', 'TSM', 'SPY']
f=data.Frequency.D
y=3
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# NVDA              0.116889        0.623283  0.268475  3.440573
# SEME.PA          -0.001541        0.309882  0.073205  3.059582
# SMH.L            -0.015345        0.367934 -0.004989  2.856687
# SPY              -0.073226        0.230159 -0.021065  3.508374
# TSM              -0.174884        0.375090  0.570866  4.593326
# VVSM.DE           0.015969        0.331279 -0.019060  2.812506
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# NVDA                    0.059979            0.076024      0.568820
# SEME.PA                 0.031493            0.039747      0.153383
# SMH.L                   0.038016            0.048135      0.145792
# SPY                     0.023983            0.032370     -0.209971
# TSM                     0.034612            0.045980     -0.307054
# VVSM.DE                 0.034237            0.042955      0.221247
#
#          Max Drawdown
# NVDA        -0.608015
# ...

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### Private Equity
#
# - IPRA.AS/IPRV.AS - [iShares Listed Private Equity UCITS ETF Acc/Dist](https://www.blackrock.com/fr/particuliers/products/325781/ishares-listed-private-equity-ucits-etf)
# - IQQL.DE/CBUW.DE [iShares Listed Private Equity UCITS ETF Dist](https://www.blackrock.com/fr/particuliers/products/325781/ishares-listed-private-equity-ucits-etf)

# %%
t=['IPRA.AS', 'IPRV.AS', 'IQQL.DE', 'SPY']
f=data.Frequency.D
y=3
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# IPRA.AS          -0.212239        0.279101  0.007517  3.304446
# IPRV.AS          -0.207808        0.240707 -0.234982  3.717023
# IQQL.DE          -0.207324        0.238378 -0.192824  3.620529
# SPY              -0.087844        0.229636 -0.017270  3.516398
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# IPRA.AS                 0.029565            0.037362     -0.648107
# IPRV.AS                 0.026527            0.034844     -0.766151
# IQQL.DE                 0.026133            0.034546     -0.773508
# SPY                     0.023974            0.032370     -0.276297
#
#          Max Drawdown
# IPRA.AS     -0.342380
# IPRV.AS     -0.255901
# IQQL.DE     -0.256433
# SPY         -0.220948

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### Real Estate
#
# See https://www.justetf.com/en/how-to/invest-in-real-estate.html
#
# - DPYA.L, IWDP.L, DPYE.L - [iShares Developed Markets Property Yield UCITS ETF Acc/Dist/EUR](https://www.blackrock.com/fr/particuliers/products/251801/ishares-developed-markets-property-yield-ucits-etf)
# - VNQ - [Vanguard Real Estate ETF](https://investor.vanguard.com/investment-products/etfs/profile/vnq)

# %%
t=['DPYA.L', 'DPYE.L', 'VNQ']
f=data.Frequency.D
y=5
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# DPYA.L          -0.009772        0.198204 -0.278912  13.715312
# DPYE.L          -0.007838        0.192193 -0.210751  14.154297
# VNQ              0.038841        0.246331 -1.286304  22.927528
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# DPYA.L                 0.018770            0.030423      0.050137
# DPYE.L                 0.017862            0.029300      0.055706
# VNQ                    0.024202            0.037227      0.289673
#
#         Max Drawdown
# DPYA.L     -0.429602
# DPYE.L     -0.414626
# VNQ        -0.423982

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### MLP ETFs
#
# See https://www.justetf.com/en/how-to/invest-in-mlp.html
#
# - MLPD.L - [Invesco Morningstar US Energy Infrastructure MLP UCITS ETF Dist]()

# %%
t=['MLPD.L', 'SPY']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# MLPD.L          -0.087731        0.317540 -1.062346  25.223291
# SPY              0.110885        0.173734 -0.559158  16.418697
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# MLPD.L                 0.029708            0.048679     -0.124675
# SPY                    0.016236            0.026958      0.735884
#
#         Max Drawdown
# MLPD.L     -0.888660
# SPY        -0.337173

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ## USD Bonds ETFs

# %% [markdown]
# ### USD Government Bonds
# - IEF - [iShares 7-10 Year Treasury Bond ETF](https://www.ishares.com/us/products/239456/ishares-710-year-treasury-bond-etf)
# - ISHG - [iShares 1-3 Year International Treasury Bond ETF](https://www.blackrock.com/americas-offshore/en/products/239829/ishares-13-year-international-treasury-bond-etf)
# - SHY - [iShares 1-3 Year Treasury Bond ETF](https://www.blackrock.com/us/individual/products/239452/ishares-13-year-treasury-bond-etf)

# %%
t=['IEF', 'ISHG', 'SHY']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
ts.stats()
# Out:
#       Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# IEF            0.010756        0.063695  0.116094   6.880908
# ISHG          -0.024651        0.072344  0.153587   4.922659
# SHY            0.007272        0.013001  1.076107  20.144167
#
#       Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  Max Drawdown
# IEF                  0.006102            0.008967      0.201073     -0.226478
# ISHG                 0.007207            0.010181     -0.305425     -0.321157
# SHY                  0.000766            0.001817      0.565858     -0.057071

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### USD Corporate Bonds
#
# - LQDA.L/LQDE.L/LQEE - [iShares $ Corp Bond UCITS ETF Acc/Dist/EUR](https://www.blackrock.com/fr/intermediaries/products/251832/ishares-corporate-bond-ucits-etf)
# - AGG - [iShares Core U.S. Aggregate Bond ETF](https://www.blackrock.com/us/individual/products/239458/ishares-core-total-us-bond-market-etf)
# - BND - [Vanguard Total Bond Market Index Fund](https://investor.vanguard.com/investment-products/etfs/profile/bnd)

# %%
t=['LQDA.L', 'LQDE.L', 'LQEE.L', 'AGG', 'BND']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness   Kurtosis  \
# AGG              0.007082        0.056790 -1.533071  29.197359
# BND              0.007394        0.059271 -1.287168  50.119142
# LQDA.L           0.011522        0.101230 -2.659469  61.834732
# LQDE.L          -0.020552        0.100650 -2.968837  57.232770
# LQEE.L          -0.041552        0.097764 -2.017743  43.392483
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# AGG                    0.005360            0.008368      0.153429
# BND                    0.003805            0.008419      0.154731
# LQDA.L                 0.006825            0.014604      0.165792
# LQDE.L                 0.007853            0.014965     -0.154094
# LQEE.L                 0.008320            0.014601     -0.377609
#
#         Max Drawdown
# AGG        -0.184329
# BND        -0.185821
# LQDA.L     -0.250952
# LQDE.L     -0.296593
# LQEE.L     -0.320403

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### USD Commodities

# %% [markdown]
# #### Precious Metals
# - IGLN.L - [iShares Physical Gold ETC](https://www.blackrock.com/fr/intermediaries/products/258441/ishares-physical-gold-etc-fund)
# - SGLD.L - [Invesco Physical Gold ETC](https://etf.invesco.com/fr/private/fr/product/invesco-physical-gold-etc/trading-information)
# - GLD - [SPDR Gold Shares](https://www.spdrgoldshares.com/)
# - IAU - [iShares Gold Trust](https://www.blackrock.com/us/individual/products/239561/)
# - SGOL - [abrdn Physical Gold Shares ETF](https://www.abrdn.com/en-us/us/investor/fund-details/aberdeen-standard-physical-gold-shares-etf/common-stock/us00326a1043)

# %%
t=['IGLN.L', 'SGLD.L', 'GLD', 'IAU', 'SGOL']
f=data.Frequency.D
y=10
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
ts.stats()
# Out:
#         Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# GLD              0.016602        0.150495 -0.424378  8.729702
# IAU              0.018077        0.150577 -0.425761  8.713445
# IGLN.L           0.018915        0.148587 -0.383312  9.544838
# SGLD.L           0.018764        0.148294 -0.316329  9.234486
# SGOL             0.017696        0.150437 -0.397244  8.729305
#
#         Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# GLD                    0.015499            0.022322      0.187472
# IAU                    0.015508            0.022362      0.197361
# IGLN.L                 0.015035            0.022200      0.203615
# SGLD.L                 0.014895            0.022084      0.202654
# SGOL                   0.015419            0.022326      0.194822
#
#         Max Drawdown
# GLD        -0.353115
# IAU        -0.349359
# IGLN.L     -0.348874
# SGLD.L     -0.349484
# SGOL       -0.352722

# %%
ts.plot()

# %%
ts.plot_corr()

# %% [markdown]
# ### Other Commodities
# - DBC - [Invesco DB Commodity Index Tracking Fund](https://www.invesco.com/us/financial-products/etfs/product-detail?audienceType=Investor&ticker=DBC)
# - CMOD.L - [Invesco Bloomberg Commodity UCITS ETF Acc](https://etf.invesco.com/fr/private/fr/product/invesco-bloomberg-commodity-ucits-etf/trading-information)
# - GSG - [iShares S&P GSCI Commodity-Indexed Trust](https://www.blackrock.com/americas-offshore/en/products/239757/ishares-sp-gsci-commodityindexed-trust-fund)
# - SXRS.DE - [iShares Diversified Commodity Swap UCITS ETF (DE)](CMSE.DE)

# %%
t=['DBC', 'CMOD.L', 'GSG', 'SXRS.DE']
f=data.Frequency.D
y=1
ts=data.MultiTimeSeries(t, years=y, frequency=f)
df=ts.history()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
ts.stats()
# Out:
#          Annualized Return  Annualized Vol  Skewness  Kurtosis  \
# CMOD.L           -0.186662        0.202895 -0.358500  4.461803
# DBC              -0.146325        0.231781 -0.578249  4.657936
# GSG              -0.206471        0.266667 -0.554664  4.079504
# SXRS.DE          -0.167994        0.193210 -0.225382  4.160999
#
#          Cornish-Fisher VaR (5%)  Historic CVaR (5%)  Sharpe Ratio  \
# CMOD.L                  0.022655            0.031398     -0.836211
# DBC                     0.026356            0.035331     -0.530304
# GSG                     0.030592            0.040670     -0.665641
# SXRS.DE                 0.021158            0.029285     -0.788076
#
#          Max Drawdown
# CMOD.L      -0.247522
# DBC         -0.252639
# GSG         -0.282840
# SXRS.DE     -0.249814

# %%
ts.plot()

# %%
ts.plot_corr()
