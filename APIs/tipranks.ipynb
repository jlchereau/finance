# %% [markdown]
# # TipRanks
#
# - https://www.tipranks.com
# - https://github.com/janlukasschroeder/tipranks-api-v2/blob/master/index.js

# %%
import requests
from requests.exceptions import HTTPError
import time

# %%
BASE_URL='https://www.tipranks.com/api/stocks/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}

def tipranks(ticker: str):
    json = None
    try:
        timestamp = int(time.time()) # Unix epoch in secs
        response = requests.get(f'{BASE_URL}getNewsSentiments/?ticker={ticker}&break={timestamp}', headers=headers)
        #response = requests.get(f'{BASE_URL}getData/?name={ticker}&benchmark=1&period=3&break={timestamp}', headers=headers)
        #response = requests.get(f'{BASE_URL}gettrendingstocks/?daysago=30&which=most&break={timestamp}', headers=headers)
        response.raise_for_status()
        json = response.json()

    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'Other error occurred: {err}')

    return json

# %%
tipranks('msft')
# Out:
# {'ticker': 'MSFT',
#  'companyName': 'Microsoft',
#  'buzz': {'articlesInLastWeek': 253, 'weeklyAverage': 398.25, 'buzz': 0.6352},
#  'sentiment': {'bullishPercent': 0.7826, 'bearishPercent': 0.2174},
#  'sector': [{'stockID': 11425,
#    'ticker': 'LNW',
#    'companyName': 'Light & Wonder',
#    'bullishPercent': 1.0,
#    'bearishPercent': 0.0,
#    'currencyTypeId': 1.0},
#   {'stockID': 96688,
#    'ticker': 'APP',
#    'companyName': 'AppLovin',
#    'bullishPercent': 1.0,
#    'bearishPercent': 0.0,
#    'currencyTypeId': 1.0},
#   {'stockID': 10446,
#    'ticker': 'ONTO',
#    'companyName': 'Onto Innovation',
#    'bullishPercent': 1.0,
#    'bearishPercent': 0.0,
#    'currencyTypeId': 1.0},
#   {'stockID': 93587,
#    'ticker': 'DDI',
#    'companyName': 'Doubledown Interactive Co',
#    'bullishPercent': 1.0,
#    'bearishPercent': 0.0,
#    'currencyTypeId': 1.0},
#   {'stockID': 16982,
#    'ticker': 'MODN',
#    'companyName': 'Model N',
#    'bullishPercent': 1.0,
#    'bearishPercent': 0.0,
#    'currencyTypeId': 1.0}],
#  'sectorAverageBullishPercent': 0.6437,
#  'score': 0.6753,
#  'wordCloud': [{'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'committed another error',
#    'effectiveDate': '2023-08-10T00:00:00',
#    'grade': 4,
#    'wordCloudEventID': 4174407,
#    'addedOn': '2023-08-11T08:03:24.007'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'generated $24 billion in revenue',
#    'effectiveDate': '2023-08-08T00:00:00',
#    'grade': 5,
#    'wordCloudEventID': 4172142,
#    'addedOn': '2023-08-09T08:05:27.997'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'grew more than 68%',
#    'effectiveDate': '2023-08-09T00:00:00',
#    'grade': 8,
#    'wordCloudEventID': 4173347,
#    'addedOn': '2023-08-10T08:07:45.45'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'having enormous high margin revenue potential',
#    'effectiveDate': '2023-08-08T00:00:00',
#    'grade': 6,
#    'wordCloudEventID': 4172140,
#    'addedOn': '2023-08-09T08:05:27.997'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'impeding the companys growth',
#    'effectiveDate': '2023-08-12T00:00:00',
#    'grade': 6,
#    'wordCloudEventID': 4176358,
#    'addedOn': '2023-08-13T16:00:58.327'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'raising its guidance',
#    'effectiveDate': '2023-08-11T00:00:00',
#    'grade': 8,
#    'wordCloudEventID': 4175652,
#    'addedOn': '2023-08-12T08:05:43.257'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'tipping toward oversold',
#    'effectiveDate': '2023-08-10T00:00:00',
#    'grade': 9,
#    'wordCloudEventID': 4174406,
#    'addedOn': '2023-08-11T08:03:24.007'},
#   {'ticker': 'MSFT',
#    'stockID': 10324,
#    'text': 'was a 15% year-over-year increase',
#    'effectiveDate': '2023-08-08T00:00:00',
#    'grade': 5,
#    'wordCloudEventID': 4172141,
#    'addedOn': '2023-08-09T08:05:27.997'}],
#  'counts': [{'buy': 1,
#    'sell': 0,
#    'all': 18,
#    'weekStart': '2023-08-13T00:00:00',
#    'neutral': 17},
#   {'buy': 21,
#    'sell': 6,
#    'all': 269,
#    'weekStart': '2023-08-06T00:00:00',
#    'neutral': 242},
#   {'buy': 25,
#    'sell': 5,
#    'all': 244,
#    'weekStart': '2023-07-30T00:00:00',
#    'neutral': 214},
#   {'buy': 79,
#    'sell': 26,
#    'all': 604,
#    'weekStart': '2023-07-23T00:00:00',
#    'neutral': 499},
#   {'buy': 77,
#    'sell': 29,
#    'all': 598,
#    'weekStart': '2023-07-16T00:00:00',
#    'neutral': 492},
#   {'buy': 49,
#    'sell': 34,
#    'all': 550,
#    'weekStart': '2023-07-09T00:00:00',
#    'neutral': 467},
#   {'buy': 37,
#    'sell': 4,
#    'all': 226,
#    'weekStart': '2023-07-02T00:00:00',
#    'neutral': 185},
#   {'buy': 34,
#    'sell': 5,
#    'all': 324,
#    'weekStart': '2023-06-25T00:00:00',
#    'neutral': 285},
#   {'buy': 29,
#    'sell': 17,
#    'all': 251,
#    'weekStart': '2023-06-18T00:00:00',
#    'neutral': 205},
#   {'buy': 39,
#    'sell': 8,
#    'all': 360,
#    'weekStart': '2023-06-11T00:00:00',
#    'neutral': 313},
#   {'buy': 29,
#    'sell': 4,
#    'all': 308,
#    'weekStart': '2023-06-04T00:00:00',
#    'neutral': 275},
#   {'buy': 29,
#    'sell': 4,
#    'all': 278,
#    'weekStart': '2023-05-28T00:00:00',
#    'neutral': 245},
#   {'buy': 38,
#    'sell': 11,
#    'all': 403,
#    'weekStart': '2023-05-21T00:00:00',
#    'neutral': 354},
#   {'buy': 28,
#    'sell': 9,
#    'all': 342,
#    'weekStart': '2023-05-14T00:00:00',
#    'neutral': 305},
#   {'buy': 32,
#    'sell': 11,
#    'all': 296,
#    'weekStart': '2023-05-07T00:00:00',
#    'neutral': 253},
#   {'buy': 32,
#    'sell': 10,
#    'all': 268,
#    'weekStart': '2023-04-30T00:00:00',
#    'neutral': 226},
#   {'buy': 121,
#    'sell': 23,
#    'all': 788,
#    'weekStart': '2023-04-23T00:00:00',
#    'neutral': 644},
#   {'buy': 33,
#    'sell': 9,
#    'all': 318,
#    'weekStart': '2023-04-16T00:00:00',
#    'neutral': 276},
#   {'buy': 27,
#    'sell': 6,
#    'all': 242,
#    'weekStart': '2023-04-09T00:00:00',
#    'neutral': 209},
#   {'buy': 17,
#    'sell': 13,
#    'all': 233,
#    'weekStart': '2023-04-02T00:00:00',
#    'neutral': 203},
#   {'buy': 19,
#    'sell': 6,
#    'all': 287,
#    'weekStart': '2023-03-26T00:00:00',
#    'neutral': 262},
#   {'buy': 14,
#    'sell': 5,
#    'all': 264,
#    'weekStart': '2023-03-19T00:00:00',
#    'neutral': 245},
#   {'buy': 23,
#    'sell': 4,
#    'all': 169,
#    'weekStart': '2023-03-12T00:00:00',
#    'neutral': 142}],
#  'sectorId': 17349,
#  'creationDate': '2023-08-14T15:01:36.278778+00:00',
#  'sectorAverageNewsScore': 0.5306}
