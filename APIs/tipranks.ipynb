# %% [markdown]
# # TipRanks
#
# - https://www.tipranks.com
# - https://github.com/janlukasschroeder/tipranks-api-v2/blob/master/index.js

# %%
# !pip3 install -q -U requests

# %%
import requests
from requests.exceptions import HTTPError
import time

# %%
BASE_URL='https://www.tipranks.com/api/stocks/'
HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}
TICKER = 'MSFT'

# %%
def tipranks_req(ticker: str):
    json = None
    try:
        timestamp = int(time.time()) # Unix epoch in secs
        #response = requests.get(f'{BASE_URL}getData/?name={ticker}&benchmark=1&period=3&break={timestamp}', headers=HEADERS)
        response = requests.get(f'{BASE_URL}gettrendingstocks/?daysago=30&which=most&break={timestamp}', headers=HEADERS)
        #response = requests.get(f'{BASE_URL}getNewsSentiments/?ticker={ticker}&break={timestamp}', headers=HEADERS)
        response.raise_for_status()
        json = response.json()

    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'Other error occurred: {err}')

    return json

# %%
tipranks_req(TICKER)
# Out:
# [{'ticker': 'NFLX',
#   'popularity': 35,
#   'sentiment': 21,
#   'consensusScore': 1.8,
#   'operations': None,
#   'sector': 'COMMUNICATION SERVICES',
#   'sectorID': 20703,
#   'market': 'NASDAQ',
#   'marketCap': 326680597007,
#   'marketCapCurrencyId': 1,
#   'buy': 23,
#   'sell': 2,
#   'hold': 10,
#   'priceTarget': 786.34,
#   'stockCurrencyTypeID': 1,
#   'rating': 4,
#   'companyName': 'Netflix',
#   'quarterlyTrend': 4,
#   'lastRatingDate': '2024-10-21T00:00:00',
#   'marketCountryId': 1,
#   'stockId': 12584,
#   'ptConsensus': [{'period': 3,
#     'bench': 1,
#     'priceTarget': 785.55,
#     'high': 925.0,
#     'low': 550.0,
#     'priceTargetCurrency': 1,
#     'priceTargetCurrencyCode': 'USD'},
#    {'period': 0,
#     'bench': 0,
#     'priceTarget': 786.34,
#     'high': 925.0,
#     'low': 550.0,
#     'priceTargetCurrency': 1,
#     'priceTargetCurrencyCode': 'USD'}]},
#  {'ticker': 'META',
#   'popularity': 31,
#   'sentiment': 29,
# ...
