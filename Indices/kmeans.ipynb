# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.preprocessing import normalize

# %%
DATA_FILE_1 = './data/us_data.csv'
DATA_FILE_2 = './data/adr_data.csv'

# %%
df1 = pd.read_csv(DATA_FILE, index_col='ticker')
df.describe()
# Out:
#        recommendationMean          beta   trailingEps    forwardEps  \
# count        2.552000e+03  2.552000e+03  2.552000e+03  2.552000e+03
# mean        -4.037175e-17  5.359697e-17  4.176388e-18 -1.113703e-17
# std          9.723742e-01  9.727772e-01  9.727772e-01  9.727772e-01
# min         -3.336604e+00 -4.599139e+00 -1.165487e+01 -8.148706e+00
# 25%         -6.943033e-01 -5.678812e-01 -4.795602e-01 -5.715828e-01
# 50%         -9.556556e-02 -8.929228e-02 -6.209544e-02 -2.255906e-01
# 75%          6.488376e-01  4.659344e-01  3.312013e-01  3.014444e-01
# max          3.602579e+00  1.391021e+01  5.065560e+00  9.126166e+00
#
#           forwardPE     bookValue   priceToBook  ebitdaMargins  profitMargins  \
# count  2.552000e+03  2.552000e+03  2.552000e+03   2.552000e+03   2.552000e+03
# mean  -2.157800e-17  1.670555e-17  1.183310e-17  -3.480323e-18  -6.960646e-18
# std    9.727772e-01  9.727772e-01  9.727772e-01   9.709622e-01   9.727772e-01
# ...

# %%
plt.figure(figsize=(10, 7))  
#plt.scatter(df_norm['recommendationMean'], df_norm['Beta'], c=cluster.labels_) 
plt.scatter(df['forwardEps'], df['ebitdaMargins'], c=df['zacks_rank']) 
plt.xlabel('forwardEps')
plt.ylabel('ebitdaMargins')
# Out:
# Text(0, 0.5, 'ebitdaMargins')

# %%
# https://www.digitalocean.com/community/tutorials/normalize-data-in-python
df_norm = normalize(df, axis=0)

# %%
N = range(1, 20)
kmeans = []
for i in N:
    kmeans.append(KMeans(n_clusters=i))

# %%
scores = []
for i in range(len(kmeans)):
    scores.append(kmeans[i].fit(df_norm).score(df_norm))
# Out:
# /Users/jlchereau/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/jlchereau/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/jlchereau/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.plot(N,scores)
plt.xlabel('Number of Clusters - Normalized')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
#cluster = AgglomerativeClustering(n_clusters = 2, metric='euclidean', linkage='ward')
#cluster.fit_predict(data_scaled)
km = KMeans(n_clusters=5)
km.fit(df_norm)
predictions = km.predict(df_norm)
predictions
# Out:
# /Users/jlchereau/Library/Python/3.9/lib/python/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([3, 4, 0, ..., 4, 4, 1], dtype=int32)

# %%
df_norm[:,0]
# Out:
# array([ 0.00328006,  0.02013951,  0.00301788, ..., -0.02230499,
#        -0.00485188, -0.01923988])

# %%
plt.figure(figsize=(10, 7))  
#plt.scatter(df_norm['recommendationMean'], df_norm['Beta'], c=cluster.labels_) 
plt.scatter(df_norm[:,0], df_norm[:,16], c=predictions) 
plt.xlabel('Recommendation Mean')
plt.ylabel('Zacks rank')
# Out:
# Text(0, 0.5, 'Zacks rank')

# %%
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')
x = np.array(sub_df['Ward'])
y = np.array(sub_df['IUCR'])
z = np.array(sub_df['District'])

ax.set_xlabel('Ward')
ax.set_ylabel('IUCR')
ax.set_zlabel('District')

ax.scatter(x,y,z, marker="o", c = predictions, s=60, cmap="jet")
ax.view_init(azim=0)
#print(ax.azim)
plt.show()
