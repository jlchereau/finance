# %% [markdown]
# # Collect Data
#
# This notebook uses a list of tickers to create `./data/features.csv` and `./data/labels.csv` from data found on Yahoo Finance and Zacks.com.

# %% [markdown]
# ## Installation

# %%
#%pip install --upgrade numpy
#%pip install --upgrade pandas
#%pip install --upgrade yfinance

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %%
TICKERS_FILE = './data/adr_tickers.csv'
FEATURES_FILE = './data/adr_features.csv'
LABELS_FILE = './data/adr_labels.csv'

#TICKERS_FILE = './data/us_tickers.txt'
#FEATURES_FILE = './data/us_features.csv'
#LABELS_FILE = './data/us_labels.csv'

# %% [markdown]
# ## Tickers
#
# Source: https://github.com/rreichel3/US-Stock-Symbols

# %%
df = pd.read_csv(TICKERS_FILE, header=None, dtype=str, keep_default_na=False)
#for index, row in df.iterrows():
#    if type(row[0]) is not str:
#        print(index, row[0])
t = df[0].to_list()
t.sort()
len(t)
# Out:
# 463

# %% [markdown]
# ## Features
#
# Collect feature data from Yahoo Finance, using:
#
# - https://github.com/ranaroussi/yfinance

# %%
ticker = yf.Ticker('MSFT')
#ticker.actions
#ticker.dividends
#ticher.history(period='5y')
ticker.financials
# Out:
#                                                         2023-06-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.189786
# Normalized EBITDA                                   102384000000.0
# Total Unusual Items                                            NaN
# Total Unusual Items Excluding Goodwill                         NaN
# Net Income From Continuing Operation Net Minori...   72361000000.0
# Reconciled Depreciation                              13861000000.0
# Reconciled Cost Of Revenue                           65863000000.0
# EBIT                                                 88523000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    72361000000.0
# Net Income From Continuing And Discontinued Ope...   72361000000.0
# Total Expenses                                      123392000000.0
# Total Operating Income As Reported                   88523000000.0
# Diluted Average Shares                                7472000000.0
# Basic Average Shares                                  7446000000.0
# Diluted EPS                                                   9.68
# Basic EPS                                                     9.72
# Diluted NI Availto Com Stockholders                  72361000000.0
# Net Income Common Stockholders                       72361000000.0
# Net Income                                           72361000000.0
# Net Income Including Noncontrolling Interests        72361000000.0
# Net Income Continuous Operations                     72361000000.0
# Tax Provision                                        16950000000.0
# Pretax Income                                        89311000000.0
# Other Income Expense                                   788000000.0
# Other Non Operating Income Expenses                    788000000.0
# Special Income Charges                                         NaN
# Write Off                                                      NaN
# Gain On Sale Of Security                                       NaN
# Net Non Operating Interest Income Expense                      NaN
# Interest Expense Non Operating                                 NaN
# Interest Income Non Operating                                  NaN
# Operating Income                                     88523000000.0
# Operating Expense                                    57529000000.0
# Research And Development                             27195000000.0
# Selling General And Administration                   30334000000.0
# Selling And Marketing Expense                        22759000000.0
# General And Administrative Expense                    7575000000.0
# Other Gand A                                          7575000000.0
# Gross Profit                                        146052000000.0
# Cost Of Revenue                                      65863000000.0
# Total Revenue                                       211915000000.0
# Operating Revenue                                   211915000000.0
#
#                                                         2022-06-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.131134
# Normalized EBITDA                                    97843000000.0
# Total Unusual Items                                    334000000.0
# Total Unusual Items Excluding Goodwill                 334000000.0
# Net Income From Continuing Operation Net Minori...   72738000000.0
# Reconciled Depreciation                              14460000000.0
# Reconciled Cost Of Revenue                           62650000000.0
# EBIT                                                 83383000000.0
# Net Interest Income                                     31000000.0
# Interest Expense                                      2063000000.0
# Interest Income                                       2094000000.0
# Normalized Income                                    72738000000.0
# Net Income From Continuing And Discontinued Ope...   72738000000.0
# Total Expenses                                      114887000000.0
# Total Operating Income As Reported                   83383000000.0
# Diluted Average Shares                                7540000000.0
# Basic Average Shares                                  7496000000.0
# Diluted EPS                                                   9.65
# Basic EPS                                                      9.7
# Diluted NI Availto Com Stockholders                  72738000000.0
# Net Income Common Stockholders                       72738000000.0
# Net Income                                           72738000000.0
# Net Income Including Noncontrolling Interests        72738000000.0
# Net Income Continuous Operations                     72738000000.0
# Tax Provision                                        10978000000.0
# Pretax Income                                        83716000000.0
# Other Income Expense                                   333000000.0
# Other Non Operating Income Expenses                    333000000.0
# Special Income Charges                                -101000000.0
# Write Off                                              101000000.0
# Gain On Sale Of Security                               435000000.0
# Net Non Operating Interest Income Expense               31000000.0
# Interest Expense Non Operating                        2063000000.0
# Interest Income Non Operating                         2094000000.0
# Operating Income                                     83383000000.0
# Operating Expense                                    52237000000.0
# Research And Development                             24512000000.0
# Selling General And Administration                   27725000000.0
# Selling And Marketing Expense                        21825000000.0
# General And Administrative Expense                    5900000000.0
# Other Gand A                                          5900000000.0
# Gross Profit                                        135620000000.0
# Cost Of Revenue                                      62650000000.0
# Total Revenue                                       198270000000.0
# Operating Revenue                                   198270000000.0
#
#                                                         2021-06-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.138266
# Normalized EBITDA                                    81602000000.0
# Total Unusual Items                                   1303000000.0
# Total Unusual Items Excluding Goodwill                1303000000.0
# Net Income From Continuing Operation Net Minori...   61271000000.0
# Reconciled Depreciation                              11686000000.0
# Reconciled Cost Of Revenue                           52232000000.0
# EBIT                                                 69916000000.0
# Net Interest Income                                   -215000000.0
# Interest Expense                                      2346000000.0
# Interest Income                                       2131000000.0
# Normalized Income                                    61271000000.0
# Net Income From Continuing And Discontinued Ope...   61271000000.0
# Total Expenses                                       98172000000.0
# Total Operating Income As Reported                   69916000000.0
# Diluted Average Shares                                7608000000.0
# Basic Average Shares                                  7547000000.0
# Diluted EPS                                                   8.05
# Basic EPS                                                     8.12
# Diluted NI Availto Com Stockholders                  61271000000.0
# Net Income Common Stockholders                       61271000000.0
# Net Income                                           61271000000.0
# Net Income Including Noncontrolling Interests        61271000000.0
# Net Income Continuous Operations                     61271000000.0
# Tax Provision                                         9831000000.0
# Pretax Income                                        71102000000.0
# Other Income Expense                                  1186000000.0
# Other Non Operating Income Expenses                   1186000000.0
# Special Income Charges                                         NaN
# Write Off                                                      NaN
# Gain On Sale Of Security                              1303000000.0
# Net Non Operating Interest Income Expense             -215000000.0
# Interest Expense Non Operating                        2346000000.0
# Interest Income Non Operating                         2131000000.0
# Operating Income                                     69916000000.0
# Operating Expense                                    45940000000.0
# Research And Development                             20716000000.0
# Selling General And Administration                   25224000000.0
# Selling And Marketing Expense                        20117000000.0
# General And Administrative Expense                    5107000000.0
# Other Gand A                                          5107000000.0
# Gross Profit                                        115856000000.0
# Cost Of Revenue                                      52232000000.0
# Total Revenue                                       168088000000.0
# Operating Revenue                                   168088000000.0
#
#                                                         2020-06-30
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                            0.16
# Normalized EBITDA                                    65755000000.0
# Total Unusual Items                                     28000000.0
# Total Unusual Items Excluding Goodwill                  28000000.0
# Net Income From Continuing Operation Net Minori...   44281000000.0
# Reconciled Depreciation                              12796000000.0
# Reconciled Cost Of Revenue                           46078000000.0
# EBIT                                                 52959000000.0
# Net Interest Income                                     89000000.0
# Interest Expense                                      2591000000.0
# Interest Income                                       2680000000.0
# Normalized Income                                    44281000000.0
# Net Income From Continuing And Discontinued Ope...   44281000000.0
# Total Expenses                                       90056000000.0
# Total Operating Income As Reported                   52959000000.0
# Diluted Average Shares                                7683000000.0
# Basic Average Shares                                  7610000000.0
# Diluted EPS                                                   5.76
# Basic EPS                                                     5.82
# Diluted NI Availto Com Stockholders                  44281000000.0
# Net Income Common Stockholders                       44281000000.0
# Net Income                                           44281000000.0
# Net Income Including Noncontrolling Interests        44281000000.0
# Net Income Continuous Operations                     44281000000.0
# Tax Provision                                         8755000000.0
# Pretax Income                                        53036000000.0
# Other Income Expense                                    77000000.0
# Other Non Operating Income Expenses                     77000000.0
# Special Income Charges                                         NaN
# Write Off                                                      NaN
# Gain On Sale Of Security                                28000000.0
# Net Non Operating Interest Income Expense               89000000.0
# Interest Expense Non Operating                        2591000000.0
# Interest Income Non Operating                         2680000000.0
# Operating Income                                     52959000000.0
# Operating Expense                                    43978000000.0
# Research And Development                             19269000000.0
# Selling General And Administration                   24709000000.0
# Selling And Marketing Expense                        19598000000.0
# General And Administrative Expense                    5111000000.0
# Other Gand A                                          5111000000.0
# Gross Profit                                         96937000000.0
# Cost Of Revenue                                      46078000000.0
# Total Revenue                                       143015000000.0
# Operating Revenue                                   143015000000.0

# %% [markdown]
# Most relevant features (columns) are listed at:
#
# - https://yourfinancebook.com/stock-market-financial-metrics/

# %%
columns = [
    'shortName',
    'sector',
    'industry',
    # Stock metrics
    'recommendationMean',
    'numberOfAnalystOpinions',
    'overallRisk',
    'beta',
    # Earnings per Share (EPS)
    'previousClose',
    'trailingEps',
    'forwardEps',
    # Price to earnings ratio (P/E)
    'trailingPE',
    'forwardPE',
    #'trailingPegRatio',
    'pegRatio',
    # Price to book value ratio (P/B)
    'bookValue',
    'priceToBook',
    # Enterprise value
    'enterpriseToRevenue',
    'enterpriseToEbitda',
    # Profit margin
    'ebitdaMargins',
    'profitMargins',
    'earningsGrowth',
    'revenueGrowth',
    # Dividend payout ratio and Dividend yield
    # 'dividendRate',
    'dividendYield',
    'payoutRatio',
    'fiveYearAvgDividendYield',
    # Price to free cash flow ratio (lower is better - below 10)
    'enterpriseValue',
    'freeCashflow',
    # Debt to equity ratio (DE)
    'debtToEquity',
    # Return on assets (ROA)
    'returnOnAssets',
    # Return on equity (ROE)
    'returnOnEquity',
    # Quick and current ratios
    'quickRatio',
    'currentRatio',
]

features = pd.DataFrame(index = t, columns=columns)

for idx in features.index:
    ticker = yf.Ticker(idx)
    try:
        info = ticker.info
        for c in columns: 
            try:
                features.loc[idx, [c]] = info[c]
            except Exception as e:
                print (idx, e) # This yields a NaN
    except Exception as e:
        print (idx, e)
features
# Out:
# AACG 'overallRisk'
# AACG 'trailingPE'
# AACG 'earningsGrowth'
# AACG 'dividendYield'
# AACG 'fiveYearAvgDividendYield'
# AACG 'freeCashflow'
# ABB 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ABB?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ABCM 'overallRisk'
# ABCM 'forwardEps'
# ABCM 'trailingPE'
# ABCM 'forwardPE'
# ABCM 'pegRatio'
# ABCM 'earningsGrowth'
# ABCM 'dividendYield'
# ABCM 'fiveYearAvgDividendYield'
# ACH 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ACH?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ADAG 'overallRisk'
# ADAG 'trailingPE'
# ADAG 'pegRatio'
# ADAG 'earningsGrowth'
# ADAG 'dividendYield'
# ADAG 'fiveYearAvgDividendYield'
# ADAP 'overallRisk'
# ADAP 'trailingPE'
# ADAP 'earningsGrowth'
# ADAP 'dividendYield'
# ADAP 'fiveYearAvgDividendYield'
# ADXN 'recommendationMean'
# ADXN 'numberOfAnalystOpinions'
# ADXN 'overallRisk'
# ADXN 'forwardEps'
# ADXN 'trailingPE'
# ADXN 'forwardPE'
# ADXN 'pegRatio'
# ADXN 'earningsGrowth'
# ADXN 'dividendYield'
# ADXN 'fiveYearAvgDividendYield'
# AEG 'trailingPE'
# AEG 'earningsGrowth'
# AEG 'revenueGrowth'
# AEG 'payoutRatio'
# AENZ 'numberOfAnalystOpinions'
# AENZ 'overallRisk'
# AENZ 'forwardEps'
# AENZ 'trailingPE'
# AENZ 'forwardPE'
# AENZ 'pegRatio'
# AENZ 'earningsGrowth'
# AENZ 'dividendYield'
# AENZ 'fiveYearAvgDividendYield'
# AHG 'recommendationMean'
# AHG 'numberOfAnalystOpinions'
# AHG 'overallRisk'
# AHG 'forwardEps'
# AHG 'trailingPE'
# AHG 'forwardPE'
# AHG 'pegRatio'
# AHG 'earningsGrowth'
# AHG 'revenueGrowth'
# AHG 'dividendYield'
# AHG 'fiveYearAvgDividendYield'
# AHI 'overallRisk'
# AHI 'forwardEps'
# AHI 'trailingPE'
# AHI 'forwardPE'
# AHI 'pegRatio'
# AHI 'earningsGrowth'
# AHI 'dividendYield'
# AHI 'fiveYearAvgDividendYield'
# AIH 'overallRisk'
# AIH 'trailingPE'
# AIH 'pegRatio'
# AIH 'earningsGrowth'
# AIH 'dividendYield'
# AIH 'fiveYearAvgDividendYield'
# AIH 'freeCashflow'
# AIH 'returnOnEquity'
# AIU 'numberOfAnalystOpinions'
# AIU 'overallRisk'
# AIU 'trailingPE'
# AIU 'priceToBook'
# AIU 'enterpriseToEbitda'
# AIU 'earningsGrowth'
# AIU 'revenueGrowth'
# AIU 'dividendYield'
# AIU 'fiveYearAvgDividendYield'
# AIU 'freeCashflow'
# AIU 'debtToEquity'
# AIU 'returnOnEquity'
# AIXI 'recommendationMean'
# AIXI 'numberOfAnalystOpinions'
# AIXI 'overallRisk'
# AIXI 'beta'
# AIXI 'forwardEps'
# AIXI 'trailingPE'
# AIXI 'forwardPE'
# AIXI 'pegRatio'
# AIXI 'priceToBook'
# AIXI 'earningsGrowth'
# AIXI 'dividendYield'
# AIXI 'fiveYearAvgDividendYield'
# AIXI 'debtToEquity'
# AIXI 'returnOnEquity'
# AKO.A 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/AKO.A?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# AKO.B 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/AKO.B?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# AKTX 'numberOfAnalystOpinions'
# AKTX 'overallRisk'
# AKTX 'trailingPE'
# AKTX 'pegRatio'
# AKTX 'enterpriseToRevenue'
# AKTX 'earningsGrowth'
# AKTX 'revenueGrowth'
# AKTX 'dividendYield'
# AKTX 'fiveYearAvgDividendYield'
# AKTX 'debtToEquity'
# ALAR 'overallRisk'
# ALAR 'trailingPE'
# ALAR 'pegRatio'
# ALAR 'earningsGrowth'
# ALAR 'dividendYield'
# ALAR 'fiveYearAvgDividendYield'
# ALAR 'freeCashflow'
# AMAM 'overallRisk'
# AMAM 'trailingPE'
# AMAM 'earningsGrowth'
# AMAM 'dividendYield'
# AMAM 'fiveYearAvgDividendYield'
# AMBO 'recommendationMean'
# AMBO 'numberOfAnalystOpinions'
# AMBO 'overallRisk'
# AMBO 'forwardEps'
# AMBO 'trailingPE'
# AMBO 'forwardPE'
# AMBO 'pegRatio'
# AMBO 'earningsGrowth'
# AMBO 'dividendYield'
# AMBO 'fiveYearAvgDividendYield'
# AMOV 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/AMOV?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# AMRN 'trailingPE'
# AMRN 'earningsGrowth'
# AMRN 'dividendYield'
# AMRN 'fiveYearAvgDividendYield'
# AMTD 'numberOfAnalystOpinions'
# AMTD 'overallRisk'
# AMTD 'forwardEps'
# AMTD 'forwardPE'
# AMTD 'pegRatio'
# AMTD 'enterpriseToEbitda'
# AMTD 'dividendYield'
# AMTD 'fiveYearAvgDividendYield'
# AMTD 'freeCashflow'
# AMX 'overallRisk'
# AMX 'earningsGrowth'
# AMX 'revenueGrowth'
# AMYT 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/AMYT?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ANPC 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ANPC?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ANTE 'recommendationMean'
# ANTE 'numberOfAnalystOpinions'
# ANTE 'overallRisk'
# ANTE 'forwardEps'
# ANTE 'trailingPE'
# ANTE 'forwardPE'
# ANTE 'pegRatio'
# ANTE 'earningsGrowth'
# ANTE 'dividendYield'
# ANTE 'fiveYearAvgDividendYield'
# ARBK 'overallRisk'
# ARBK 'trailingPE'
# ARBK 'earningsGrowth'
# ARBK 'dividendYield'
# ARBK 'fiveYearAvgDividendYield'
# ARBK 'freeCashflow'
# ARGX 'trailingPE'
# ARGX 'earningsGrowth'
# ARGX 'dividendYield'
# ARGX 'fiveYearAvgDividendYield'
# ASAI 'overallRisk'
# ASAI 'fiveYearAvgDividendYield'
# ASLN 'overallRisk'
# ASLN 'beta'
# ASLN 'trailingPE'
# ASLN 'pegRatio'
# ASLN 'earningsGrowth'
# ASLN 'revenueGrowth'
# ASLN 'dividendYield'
# ASLN 'fiveYearAvgDividendYield'
# ASND 'overallRisk'
# ASND 'trailingPE'
# ASND 'pegRatio'
# ASND 'earningsGrowth'
# ASND 'dividendYield'
# ASND 'fiveYearAvgDividendYield'
# ASR 'overallRisk'
# ASR 'dividendYield'
# ASR 'fiveYearAvgDividendYield'
# ASX 'overallRisk'
# ATHE 'overallRisk'
# ATHE 'forwardEps'
# ATHE 'trailingPE'
# ATHE 'forwardPE'
# ATHE 'pegRatio'
# ATHE 'earningsGrowth'
# ATHE 'dividendYield'
# ATHE 'fiveYearAvgDividendYield'
# ATHM 'overallRisk'
# ATHM 'fiveYearAvgDividendYield'
# ATHM 'freeCashflow'
# AU 'pegRatio'
# AU 'earningsGrowth'
# AUTL 'overallRisk'
# AUTL 'trailingPE'
# AUTL 'pegRatio'
# AUTL 'earningsGrowth'
# AUTL 'revenueGrowth'
# AUTL 'dividendYield'
# AUTL 'fiveYearAvgDividendYield'
# AVAL 'overallRisk'
# AVAL 'pegRatio'
# AVAL 'enterpriseToRevenue'
# AVAL 'enterpriseToEbitda'
# AVAL 'freeCashflow'
# AVAL 'debtToEquity'
# AVAL 'quickRatio'
# AVAL 'currentRatio'
# AVDL 'overallRisk'
# AVDL 'trailingPE'
# AVDL 'earningsGrowth'
# AVDL 'revenueGrowth'
# AVDL 'dividendYield'
# AVDL 'fiveYearAvgDividendYield'
# BABA 'overallRisk'
# BABA 'beta'
# BABA 'enterpriseToRevenue'
# BABA 'enterpriseToEbitda'
# BABA 'earningsGrowth'
# BABA 'revenueGrowth'
# BABA 'dividendYield'
# BABA 'fiveYearAvgDividendYield'
# BABA 'freeCashflow'
# BABA 'debtToEquity'
# BABA 'returnOnAssets'
# BABA 'returnOnEquity'
# BABA 'quickRatio'
# BABA 'currentRatio'
# BAK 'beta'
# BAK 'trailingPE'
# BAK 'earningsGrowth'
# BAK 'dividendYield'
# BAK 'fiveYearAvgDividendYield'
# BBD 'enterpriseToEbitda'
# BBD 'freeCashflow'
# BBD 'debtToEquity'
# BBD 'quickRatio'
# BBD 'currentRatio'
# BBDO 'recommendationMean'
# BBDO 'numberOfAnalystOpinions'
# BBDO 'forwardEps'
# BBDO 'forwardPE'
# BBDO 'pegRatio'
# BBDO 'enterpriseToEbitda'
# BBDO 'freeCashflow'
# BBDO 'debtToEquity'
# BBDO 'quickRatio'
# BBDO 'currentRatio'
# BBVA 'pegRatio'
# BBVA 'enterpriseToEbitda'
# BBVA 'freeCashflow'
# BBVA 'debtToEquity'
# BBVA 'quickRatio'
# BBVA 'currentRatio'
# BCH 'overallRisk'
# BCH 'enterpriseToRevenue'
# BCH 'enterpriseToEbitda'
# BCH 'freeCashflow'
# BCH 'debtToEquity'
# BCH 'quickRatio'
# BCH 'currentRatio'
# BCS 'pegRatio'
# BCS 'enterpriseToEbitda'
# BCS 'fiveYearAvgDividendYield'
# BCS 'freeCashflow'
# BCS 'debtToEquity'
# BCS 'quickRatio'
# BCS 'currentRatio'
# BCYC 'overallRisk'
# BCYC 'trailingPE'
# BCYC 'pegRatio'
# BCYC 'earningsGrowth'
# BCYC 'dividendYield'
# BCYC 'fiveYearAvgDividendYield'
# BEDU 'numberOfAnalystOpinions'
# BEDU 'overallRisk'
# BEDU 'beta'
# BEDU 'trailingPE'
# BEDU 'pegRatio'
# BEDU 'enterpriseToRevenue'
# BEDU 'enterpriseToEbitda'
# BEDU 'earningsGrowth'
# BEDU 'revenueGrowth'
# BEDU 'dividendYield'
# BEDU 'fiveYearAvgDividendYield'
# BEDU 'freeCashflow'
# BEDU 'debtToEquity'
# BEDU 'returnOnAssets'
# BEDU 'returnOnEquity'
# BEDU 'quickRatio'
# BEDU 'currentRatio'
# BEKE 'overallRisk'
# BEKE 'earningsGrowth'
# BEKE 'dividendYield'
# BEKE 'fiveYearAvgDividendYield'
# BEST 'numberOfAnalystOpinions'
# BEST 'overallRisk'
# BEST 'trailingPE'
# BEST 'pegRatio'
# BEST 'earningsGrowth'
# BEST 'dividendYield'
# BEST 'fiveYearAvgDividendYield'
# BGNE 'trailingPE'
# BGNE 'earningsGrowth'
# BGNE 'dividendYield'
# BGNE 'fiveYearAvgDividendYield'
# BHP 'pegRatio'
# BIDU 'earningsGrowth'
# BIDU 'dividendYield'
# BIDU 'fiveYearAvgDividendYield'
# BILI 'overallRisk'
# BILI 'trailingPE'
# BILI 'earningsGrowth'
# BILI 'dividendYield'
# BILI 'fiveYearAvgDividendYield'
# BILI 'freeCashflow'
# BLCT 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/BLCT?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# BLRX 'overallRisk'
# BLRX 'trailingPE'
# BLRX 'enterpriseToRevenue'
# BLRX 'earningsGrowth'
# BLRX 'revenueGrowth'
# BLRX 'dividendYield'
# BLRX 'fiveYearAvgDividendYield'
# BLTE 'overallRisk'
# BLTE 'beta'
# BLTE 'trailingPE'
# BLTE 'pegRatio'
# BLTE 'enterpriseToRevenue'
# BLTE 'earningsGrowth'
# BLTE 'revenueGrowth'
# BLTE 'dividendYield'
# BLTE 'fiveYearAvgDividendYield'
# BLTE 'freeCashflow'
# BLTE 'debtToEquity'
# BLTE 'quickRatio'
# BMA 'overallRisk'
# BMA 'trailingPE'
# BMA 'pegRatio'
# BMA 'enterpriseToEbitda'
# BMA 'payoutRatio'
# BMA 'fiveYearAvgDividendYield'
# BMA 'freeCashflow'
# BMA 'debtToEquity'
# BMA 'quickRatio'
# BMA 'currentRatio'
# BNOX 'overallRisk'
# BNOX 'trailingPE'
# BNOX 'pegRatio'
# BNOX 'earningsGrowth'
# BNOX 'dividendYield'
# BNOX 'fiveYearAvgDividendYield'
# BNR 'overallRisk'
# BNR 'trailingPE'
# BNR 'pegRatio'
# BNR 'earningsGrowth'
# BNR 'dividendYield'
# BNR 'fiveYearAvgDividendYield'
# BNTX 'earningsGrowth'
# BNTX 'dividendYield'
# BNTX 'fiveYearAvgDividendYield'
# BPTS 'overallRisk'
# BPTS 'forwardEps'
# BPTS 'trailingPE'
# BPTS 'forwardPE'
# BPTS 'pegRatio'
# BPTS 'priceToBook'
# BPTS 'enterpriseToRevenue'
# BPTS 'earningsGrowth'
# BPTS 'revenueGrowth'
# BPTS 'dividendYield'
# BPTS 'fiveYearAvgDividendYield'
# BPTS 'debtToEquity'
# BQ 'numberOfAnalystOpinions'
# BQ 'overallRisk'
# BQ 'trailingPE'
# BQ 'pegRatio'
# BQ 'earningsGrowth'
# BQ 'dividendYield'
# BQ 'fiveYearAvgDividendYield'
# BRFS 'beta'
# BRFS 'trailingPE'
# BRFS 'enterpriseToRevenue'
# BRFS 'enterpriseToEbitda'
# BRFS 'earningsGrowth'
# BRFS 'revenueGrowth'
# BRFS 'dividendYield'
# BRFS 'fiveYearAvgDividendYield'
# BRFS 'freeCashflow'
# BRFS 'debtToEquity'
# BRFS 'returnOnAssets'
# BRFS 'returnOnEquity'
# BRFS 'quickRatio'
# BRFS 'currentRatio'
# BSAC 'overallRisk'
# BSAC 'beta'
# BSAC 'enterpriseToRevenue'
# BSAC 'enterpriseToEbitda'
# BSAC 'freeCashflow'
# BSAC 'debtToEquity'
# BSAC 'quickRatio'
# BSAC 'currentRatio'
# BSBR 'enterpriseToEbitda'
# BSBR 'freeCashflow'
# BSBR 'debtToEquity'
# BSBR 'quickRatio'
# BSBR 'currentRatio'
# BSMX 'shortName'
# BSMX 'sector'
# BSMX 'industry'
# BSMX 'recommendationMean'
# BSMX 'numberOfAnalystOpinions'
# BSMX 'overallRisk'
# BSMX 'beta'
# BSMX 'previousClose'
# BSMX 'trailingEps'
# BSMX 'forwardEps'
# BSMX 'trailingPE'
# BSMX 'forwardPE'
# BSMX 'pegRatio'
# BSMX 'bookValue'
# BSMX 'priceToBook'
# BSMX 'enterpriseToRevenue'
# BSMX 'enterpriseToEbitda'
# BSMX 'ebitdaMargins'
# BSMX 'profitMargins'
# BSMX 'earningsGrowth'
# BSMX 'revenueGrowth'
# BSMX 'dividendYield'
# BSMX 'payoutRatio'
# BSMX 'fiveYearAvgDividendYield'
# BSMX 'enterpriseValue'
# BSMX 'freeCashflow'
# BSMX 'debtToEquity'
# BSMX 'returnOnAssets'
# BSMX 'returnOnEquity'
# BSMX 'quickRatio'
# BSMX 'currentRatio'
# BTCM 'numberOfAnalystOpinions'
# BTCM 'overallRisk'
# BTCM 'trailingPE'
# BTCM 'pegRatio'
# BTCM 'earningsGrowth'
# BTCM 'dividendYield'
# BTCM 'fiveYearAvgDividendYield'
# BTCM 'freeCashflow'
# BTI 'pegRatio'
# BVN 'overallRisk'
# BVN 'earningsGrowth'
# BVN 'fiveYearAvgDividendYield'
# BVXV 'recommendationMean'
# BVXV 'overallRisk'
# BVXV 'trailingPE'
# BVXV 'pegRatio'
# BVXV 'priceToBook'
# BVXV 'enterpriseToRevenue'
# BVXV 'earningsGrowth'
# BVXV 'revenueGrowth'
# BVXV 'dividendYield'
# BVXV 'fiveYearAvgDividendYield'
# BVXV 'debtToEquity'
# BWAY 'overallRisk'
# BWAY 'trailingPE'
# BWAY 'pegRatio'
# BWAY 'earningsGrowth'
# BWAY 'dividendYield'
# BWAY 'fiveYearAvgDividendYield'
# BWAY 'debtToEquity'
# BZ 'overallRisk'
# BZ 'earningsGrowth'
# BZ 'dividendYield'
# BZ 'fiveYearAvgDividendYield'
# BZUN 'overallRisk'
# BZUN 'trailingPE'
# BZUN 'earningsGrowth'
# BZUN 'dividendYield'
# BZUN 'fiveYearAvgDividendYield'
# BZUN 'freeCashflow'
# CAJ 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/CAJ?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# CALT 'overallRisk'
# CALT 'trailingPE'
# CALT 'pegRatio'
# CALT 'bookValue'
# CALT 'priceToBook'
# CALT 'enterpriseToRevenue'
# CALT 'enterpriseToEbitda'
# CALT 'earningsGrowth'
# CALT 'dividendYield'
# CALT 'fiveYearAvgDividendYield'
# CALT 'freeCashflow'
# CAN 'trailingPE'
# CAN 'pegRatio'
# CAN 'earningsGrowth'
# CAN 'dividendYield'
# CAN 'fiveYearAvgDividendYield'
# CAN 'freeCashflow'
# CANF 'overallRisk'
# CANF 'trailingPE'
# CANF 'pegRatio'
# CANF 'earningsGrowth'
# CANF 'dividendYield'
# CANF 'fiveYearAvgDividendYield'
# CANF 'freeCashflow'
# CANG 'overallRisk'
# CANG 'trailingPE'
# CANG 'pegRatio'
# CANG 'earningsGrowth'
# CANG 'dividendYield'
# CANG 'fiveYearAvgDividendYield'
# CANG 'freeCashflow'
# CBD 'trailingPE'
# CBD 'earningsGrowth'
# CBD 'dividendYield'
# CBD 'fiveYearAvgDividendYield'
# CCM 'recommendationMean'
# CCM 'numberOfAnalystOpinions'
# CCM 'overallRisk'
# CCM 'trailingPE'
# CCM 'pegRatio'
# CCM 'priceToBook'
# CCM 'earningsGrowth'
# CCM 'dividendYield'
# CCM 'fiveYearAvgDividendYield'
# CCU 'overallRisk'
# CCU 'beta'
# CCU 'enterpriseToRevenue'
# CCU 'enterpriseToEbitda'
# CCU 'earningsGrowth'
# CCU 'freeCashflow'
# CD 'recommendationMean'
# CD 'numberOfAnalystOpinions'
# CD 'overallRisk'
# CD 'pegRatio'
# CD 'dividendYield'
# CD 'fiveYearAvgDividendYield'
# CEA 'shortName'
# CEA 'sector'
# CEA 'industry'
# CEA 'recommendationMean'
# CEA 'numberOfAnalystOpinions'
# CEA 'overallRisk'
# CEA 'beta'
# CEA 'previousClose'
# CEA 'trailingEps'
# CEA 'forwardEps'
# CEA 'trailingPE'
# CEA 'forwardPE'
# CEA 'pegRatio'
# CEA 'bookValue'
# CEA 'priceToBook'
# CEA 'enterpriseToRevenue'
# CEA 'enterpriseToEbitda'
# CEA 'ebitdaMargins'
# CEA 'profitMargins'
# CEA 'earningsGrowth'
# CEA 'revenueGrowth'
# CEA 'dividendYield'
# CEA 'payoutRatio'
# CEA 'fiveYearAvgDividendYield'
# CEA 'enterpriseValue'
# CEA 'freeCashflow'
# CEA 'debtToEquity'
# CEA 'returnOnAssets'
# CEA 'returnOnEquity'
# CEA 'quickRatio'
# CEA 'currentRatio'
# CEPU 'overallRisk'
# CEPU 'beta'
# CEPU 'pegRatio'
# CEPU 'fiveYearAvgDividendYield'
# CHT 'recommendationMean'
# CHT 'numberOfAnalystOpinions'
# CHT 'overallRisk'
# CHT 'pegRatio'
# CHT 'fiveYearAvgDividendYield'
# CIAN 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/CIAN?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# CIB 'overallRisk'
# CIB 'bookValue'
# CIB 'priceToBook'
# CIB 'enterpriseToRevenue'
# CIB 'enterpriseToEbitda'
# CIB 'freeCashflow'
# CIB 'debtToEquity'
# CIB 'quickRatio'
# CIB 'currentRatio'
# CIG 'pegRatio'
# CIG.C 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/CIG.C?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# CIH 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/CIH?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# CLGN 'overallRisk'
# CLGN 'trailingPE'
# CLGN 'pegRatio'
# CLGN 'earningsGrowth'
# CLGN 'dividendYield'
# CLGN 'fiveYearAvgDividendYield'
# CLLS 'trailingPE'
# CLLS 'pegRatio'
# CLLS 'earningsGrowth'
# CLLS 'dividendYield'
# CLLS 'fiveYearAvgDividendYield'
# CLLS 'freeCashflow'
# CMCM 'numberOfAnalystOpinions'
# CMCM 'overallRisk'
# CMCM 'trailingPE'
# CMCM 'pegRatio'
# CMCM 'earningsGrowth'
# CMCM 'dividendYield'
# CMCM 'fiveYearAvgDividendYield'
# CMMB 'overallRisk'
# CMMB 'beta'
# CMMB 'trailingPE'
# CMMB 'pegRatio'
# CMMB 'enterpriseToRevenue'
# CMMB 'enterpriseToEbitda'
# CMMB 'earningsGrowth'
# CMMB 'revenueGrowth'
# CMMB 'dividendYield'
# CMMB 'fiveYearAvgDividendYield'
# CMMB 'freeCashflow'
# CMMB 'debtToEquity'
# CMMB 'returnOnAssets'
# CMMB 'returnOnEquity'
# CMMB 'quickRatio'
# CMMB 'currentRatio'
# CMPS 'overallRisk'
# CMPS 'trailingPE'
# CMPS 'pegRatio'
# CMPS 'enterpriseToRevenue'
# CMPS 'earningsGrowth'
# CMPS 'revenueGrowth'
# CMPS 'dividendYield'
# CMPS 'fiveYearAvgDividendYield'
# CNF 'overallRisk'
# CNF 'pegRatio'
# CNF 'enterpriseToEbitda'
# CNF 'dividendYield'
# CNF 'fiveYearAvgDividendYield'
# CNF 'freeCashflow'
# CNTA 'overallRisk'
# CNTA 'beta'
# CNTA 'trailingPE'
# CNTA 'pegRatio'
# CNTA 'enterpriseToRevenue'
# CNTA 'enterpriseToEbitda'
# CNTA 'earningsGrowth'
# CNTA 'revenueGrowth'
# CNTA 'dividendYield'
# CNTA 'fiveYearAvgDividendYield'
# CNTA 'freeCashflow'
# CNTA 'debtToEquity'
# CNTA 'returnOnAssets'
# CNTA 'returnOnEquity'
# CNTA 'quickRatio'
# CNTA 'currentRatio'
# CNTB 'overallRisk'
# CNTB 'trailingPE'
# CNTB 'pegRatio'
# CNTB 'enterpriseToRevenue'
# CNTB 'earningsGrowth'
# CNTB 'revenueGrowth'
# CNTB 'dividendYield'
# CNTB 'fiveYearAvgDividendYield'
# COE 'numberOfAnalystOpinions'
# COE 'overallRisk'
# COE 'trailingPE'
# COE 'pegRatio'
# COE 'earningsGrowth'
# COE 'dividendYield'
# COE 'fiveYearAvgDividendYield'
# COE 'freeCashflow'
# COE 'returnOnEquity'
# CPAC 'overallRisk'
# CPAC 'fiveYearAvgDividendYield'
# CRESY 'recommendationMean'
# CRESY 'numberOfAnalystOpinions'
# CRESY 'overallRisk'
# CRESY 'pegRatio'
# CRESY 'earningsGrowth'
# CRESY 'fiveYearAvgDividendYield'
# CRH 'pegRatio'
# CRTO 'trailingPE'
# CRTO 'earningsGrowth'
# CRTO 'dividendYield'
# CRTO 'fiveYearAvgDividendYield'
# CS 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/CS?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# CSAN 'beta'
# CSAN 'trailingPE'
# CSAN 'enterpriseToRevenue'
# CSAN 'enterpriseToEbitda'
# CSAN 'earningsGrowth'
# CSAN 'revenueGrowth'
# CSAN 'payoutRatio'
# CSAN 'fiveYearAvgDividendYield'
# CSAN 'freeCashflow'
# CSAN 'debtToEquity'
# CSAN 'returnOnAssets'
# CSAN 'returnOnEquity'
# CSAN 'quickRatio'
# CSAN 'currentRatio'
# CUK 'recommendationMean'
# CUK 'numberOfAnalystOpinions'
# CUK 'trailingPE'
# CUK 'earningsGrowth'
# CUK 'dividendYield'
# CUK 'fiveYearAvgDividendYield'
# CX 'overallRisk'
# CX 'dividendYield'
# CX 'fiveYearAvgDividendYield'
# CYAD 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/CYAD?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# DADA 'overallRisk'
# DADA 'beta'
# DADA 'trailingPE'
# DADA 'enterpriseToRevenue'
# DADA 'enterpriseToEbitda'
# DADA 'earningsGrowth'
# DADA 'revenueGrowth'
# DADA 'dividendYield'
# DADA 'fiveYearAvgDividendYield'
# DADA 'freeCashflow'
# DADA 'debtToEquity'
# DADA 'returnOnAssets'
# DADA 'returnOnEquity'
# DADA 'quickRatio'
# DADA 'currentRatio'
# DAO 'overallRisk'
# DAO 'trailingPE'
# DAO 'pegRatio'
# DAO 'priceToBook'
# DAO 'earningsGrowth'
# DAO 'dividendYield'
# DAO 'fiveYearAvgDividendYield'
# DAO 'freeCashflow'
# DAO 'debtToEquity'
# DAO 'returnOnEquity'
# DAVA 'overallRisk'
# DAVA 'dividendYield'
# DAVA 'fiveYearAvgDividendYield'
# DBVT 'trailingPE'
# DBVT 'earningsGrowth'
# DBVT 'dividendYield'
# DBVT 'fiveYearAvgDividendYield'
# DDI 'overallRisk'
# DDI 'beta'
# DDI 'trailingPE'
# DDI 'pegRatio'
# DDI 'earningsGrowth'
# DDI 'dividendYield'
# DDI 'fiveYearAvgDividendYield'
# DDL 'overallRisk'
# DDL 'trailingPE'
# DDL 'earningsGrowth'
# DDL 'dividendYield'
# DDL 'fiveYearAvgDividendYield'
# DEO 'pegRatio'
# DIDI 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/DIDI?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# DOYU 'overallRisk'
# DOYU 'beta'
# DOYU 'enterpriseToRevenue'
# DOYU 'enterpriseToEbitda'
# DOYU 'earningsGrowth'
# DOYU 'revenueGrowth'
# DOYU 'dividendYield'
# DOYU 'fiveYearAvgDividendYield'
# DOYU 'freeCashflow'
# DOYU 'debtToEquity'
# DOYU 'returnOnAssets'
# DOYU 'returnOnEquity'
# DOYU 'quickRatio'
# DOYU 'currentRatio'
# DQ 'overallRisk'
# DQ 'dividendYield'
# DQ 'fiveYearAvgDividendYield'
# DQ 'debtToEquity'
# DRD 'pegRatio'
# DRD 'fiveYearAvgDividendYield'
# DUO 'numberOfAnalystOpinions'
# DUO 'overallRisk'
# DUO 'trailingPE'
# DUO 'pegRatio'
# DUO 'earningsGrowth'
# DUO 'dividendYield'
# DUO 'fiveYearAvgDividendYield'
# DXF 'recommendationMean'
# DXF 'numberOfAnalystOpinions'
# DXF 'overallRisk'
# DXF 'forwardEps'
# DXF 'trailingPE'
# DXF 'forwardPE'
# DXF 'pegRatio'
# DXF 'enterpriseToEbitda'
# DXF 'earningsGrowth'
# DXF 'revenueGrowth'
# DXF 'dividendYield'
# DXF 'fiveYearAvgDividendYield'
# DXF 'freeCashflow'
# E 'pegRatio'
# EBR 'trailingPE'
# EBR 'pegRatio'
# EBR 'earningsGrowth'
# EBR 'revenueGrowth'
# EBR 'fiveYearAvgDividendYield'
# EBR 'debtToEquity'
# EBR.B 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/EBR.B?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# EC 'overallRisk'
# EC 'enterpriseToRevenue'
# EC 'enterpriseToEbitda'
# EC 'freeCashflow'
# EC 'returnOnAssets'
# EC 'returnOnEquity'
# EC 'quickRatio'
# EC 'currentRatio'
# EDAP 'trailingPE'
# EDAP 'earningsGrowth'
# EDAP 'dividendYield'
# EDAP 'fiveYearAvgDividendYield'
# EDN 'overallRisk'
# EDN 'trailingPE'
# EDN 'pegRatio'
# EDN 'earningsGrowth'
# EDN 'dividendYield'
# EDN 'fiveYearAvgDividendYield'
# EDU 'overallRisk'
# EDU 'trailingPE'
# EDU 'earningsGrowth'
# EDU 'dividendYield'
# EDU 'fiveYearAvgDividendYield'
# EH 'overallRisk'
# EH 'trailingPE'
# EH 'pegRatio'
# EH 'earningsGrowth'
# EH 'dividendYield'
# EH 'fiveYearAvgDividendYield'
# EH 'freeCashflow'
# ELP 'beta'
# ELP 'enterpriseToRevenue'
# ELP 'enterpriseToEbitda'
# ELP 'earningsGrowth'
# ELP 'revenueGrowth'
# ELP 'freeCashflow'
# ELP 'debtToEquity'
# ELP 'returnOnAssets'
# ELP 'returnOnEquity'
# ELP 'quickRatio'
# ELP 'currentRatio'
# EM 'overallRisk'
# EM 'trailingPE'
# EM 'pegRatio'
# EM 'earningsGrowth'
# EM 'dividendYield'
# EM 'fiveYearAvgDividendYield'
# EM 'freeCashflow'
# ENIA 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ENIA?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ENIC 'overallRisk'
# ENIC 'pegRatio'
# ENIC 'enterpriseToRevenue'
# ENIC 'enterpriseToEbitda'
# ENIC 'earningsGrowth'
# ENIC 'freeCashflow'
# EQNR 'pegRatio'
# ERIC 'enterpriseToRevenue'
# ERIC 'enterpriseToEbitda'
# ERIC 'earningsGrowth'
# ERIC 'freeCashflow'
# ERJ 'beta'
# ERJ 'trailingPE'
# ERJ 'enterpriseToRevenue'
# ERJ 'enterpriseToEbitda'
# ERJ 'earningsGrowth'
# ERJ 'revenueGrowth'
# ERJ 'dividendYield'
# ERJ 'fiveYearAvgDividendYield'
# ERJ 'freeCashflow'
# ERJ 'debtToEquity'
# ERJ 'returnOnAssets'
# ERJ 'returnOnEquity'
# ERJ 'quickRatio'
# ERJ 'currentRatio'
# ERYP 'sector'
# ERYP 'industry'
# ERYP 'overallRisk'
# ERYP 'beta'
# ERYP 'trailingEps'
# ERYP 'forwardEps'
# ERYP 'trailingPE'
# ERYP 'pegRatio'
# ERYP 'bookValue'
# ERYP 'priceToBook'
# ERYP 'enterpriseToRevenue'
# ERYP 'enterpriseToEbitda'
# ERYP 'ebitdaMargins'
# ERYP 'profitMargins'
# ERYP 'earningsGrowth'
# ERYP 'revenueGrowth'
# ERYP 'dividendYield'
# ERYP 'payoutRatio'
# ERYP 'fiveYearAvgDividendYield'
# ERYP 'enterpriseValue'
# ERYP 'freeCashflow'
# ERYP 'debtToEquity'
# ERYP 'returnOnAssets'
# ERYP 'returnOnEquity'
# ERYP 'quickRatio'
# ERYP 'currentRatio'
# EVAX 'overallRisk'
# EVAX 'trailingPE'
# EVAX 'pegRatio'
# EVAX 'enterpriseToRevenue'
# EVAX 'earningsGrowth'
# EVAX 'revenueGrowth'
# EVAX 'dividendYield'
# EVAX 'fiveYearAvgDividendYield'
# EVAX 'freeCashflow'
# EVAX 'returnOnAssets'
# EVAX 'returnOnEquity'
# EVAX 'quickRatio'
# EVAX 'currentRatio'
# EVO 'trailingPE'
# EVO 'earningsGrowth'
# EVO 'dividendYield'
# EVO 'fiveYearAvgDividendYield'
# EXAI 'overallRisk'
# EXAI 'beta'
# EXAI 'trailingPE'
# EXAI 'earningsGrowth'
# EXAI 'dividendYield'
# EXAI 'fiveYearAvgDividendYield'
# FANH 'overallRisk'
# FANH 'earningsGrowth'
# FANH 'dividendYield'
# FANH 'fiveYearAvgDividendYield'
# FEDU 'numberOfAnalystOpinions'
# FEDU 'overallRisk'
# FEDU 'trailingPE'
# FEDU 'pegRatio'
# FEDU 'earningsGrowth'
# FEDU 'dividendYield'
# FEDU 'fiveYearAvgDividendYield'
# FENG 'numberOfAnalystOpinions'
# FENG 'overallRisk'
# FENG 'trailingPE'
# FENG 'pegRatio'
# FENG 'earningsGrowth'
# FENG 'dividendYield'
# FENG 'fiveYearAvgDividendYield'
# FENG 'freeCashflow'
# FHS 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/FHS?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# FINV 'overallRisk'
# FINV 'fiveYearAvgDividendYield'
# FLJ 'numberOfAnalystOpinions'
# FLJ 'overallRisk'
# FLJ 'forwardEps'
# FLJ 'forwardPE'
# FLJ 'pegRatio'
# FLJ 'priceToBook'
# FLJ 'earningsGrowth'
# FLJ 'dividendYield'
# FLJ 'fiveYearAvgDividendYield'
# FLJ 'debtToEquity'
# FLJ 'returnOnEquity'
# FMS 'dividendYield'
# FMS 'fiveYearAvgDividendYield'
# FMX 'overallRisk'
# FORTY 'recommendationMean'
# FORTY 'numberOfAnalystOpinions'
# FORTY 'overallRisk'
# FORTY 'forwardEps'
# FORTY 'forwardPE'
# FORTY 'pegRatio'
# FRSX 'overallRisk'
# FRSX 'trailingPE'
# FRSX 'pegRatio'
# FRSX 'earningsGrowth'
# FRSX 'dividendYield'
# FRSX 'fiveYearAvgDividendYield'
# FUTU 'overallRisk'
# FUTU 'enterpriseToEbitda'
# FUTU 'dividendYield'
# FUTU 'fiveYearAvgDividendYield'
# FUTU 'freeCashflow'
# FWP 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/FWP?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# GDS 'overallRisk'
# GDS 'trailingPE'
# GDS 'earningsGrowth'
# GDS 'dividendYield'
# GDS 'fiveYearAvgDividendYield'
# GEHI 'numberOfAnalystOpinions'
# GEHI 'overallRisk'
# GEHI 'forwardEps'
# GEHI 'trailingPE'
# GEHI 'forwardPE'
# GEHI 'pegRatio'
# GEHI 'earningsGrowth'
# GEHI 'dividendYield'
# GEHI 'fiveYearAvgDividendYield'
# GENE 'recommendationMean'
# GENE 'numberOfAnalystOpinions'
# GENE 'overallRisk'
# GENE 'forwardEps'
# GENE 'trailingPE'
# GENE 'forwardPE'
# GENE 'pegRatio'
# GENE 'earningsGrowth'
# GENE 'dividendYield'
# GENE 'fiveYearAvgDividendYield'
# GET 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/GET?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# GFI 'pegRatio'
# GGAL 'overallRisk'
# GGAL 'enterpriseToEbitda'
# GGAL 'fiveYearAvgDividendYield'
# GGAL 'freeCashflow'
# GGAL 'debtToEquity'
# GGAL 'quickRatio'
# GGAL 'currentRatio'
# GHG 'overallRisk'
# GHG 'trailingPE'
# GHG 'earningsGrowth'
# GHG 'dividendYield'
# GHG 'fiveYearAvgDividendYield'
# GLPG 'trailingPE'
# GLPG 'earningsGrowth'
# GLPG 'dividendYield'
# GLPG 'fiveYearAvgDividendYield'
# GMAB 'dividendYield'
# GMAB 'fiveYearAvgDividendYield'
# GNFT 'recommendationMean'
# GNFT 'numberOfAnalystOpinions'
# GNFT 'forwardEps'
# GNFT 'trailingPE'
# GNFT 'forwardPE'
# GNFT 'pegRatio'
# GNFT 'earningsGrowth'
# GNFT 'dividendYield'
# GNFT 'fiveYearAvgDividendYield'
# GOL 'overallRisk'
# GOL 'trailingPE'
# GOL 'priceToBook'
# GOL 'earningsGrowth'
# GOL 'dividendYield'
# GOL 'fiveYearAvgDividendYield'
# GOL 'debtToEquity'
# GOL 'returnOnEquity'
# GOTU 'overallRisk'
# GOTU 'dividendYield'
# GOTU 'fiveYearAvgDividendYield'
# GOTU 'freeCashflow'
# GRCL 'overallRisk'
# GRCL 'beta'
# GRCL 'trailingPE'
# GRCL 'pegRatio'
# GRCL 'enterpriseToRevenue'
# GRCL 'enterpriseToEbitda'
# GRCL 'earningsGrowth'
# GRCL 'revenueGrowth'
# GRCL 'dividendYield'
# GRCL 'fiveYearAvgDividendYield'
# GRCL 'freeCashflow'
# GRCL 'debtToEquity'
# GRCL 'returnOnAssets'
# GRCL 'returnOnEquity'
# GRCL 'quickRatio'
# GRCL 'currentRatio'
# GRFS 'pegRatio'
# GRFS 'dividendYield'
# GRFS 'fiveYearAvgDividendYield'
# GRFX 'recommendationMean'
# GRFX 'numberOfAnalystOpinions'
# GRFX 'overallRisk'
# GRFX 'forwardEps'
# GRFX 'trailingPE'
# GRFX 'forwardPE'
# GRFX 'pegRatio'
# GRFX 'earningsGrowth'
# GRFX 'dividendYield'
# GRFX 'fiveYearAvgDividendYield'
# GRVY 'recommendationMean'
# GRVY 'numberOfAnalystOpinions'
# GRVY 'overallRisk'
# GRVY 'forwardEps'
# GRVY 'forwardPE'
# GRVY 'pegRatio'
# GRVY 'dividendYield'
# GRVY 'fiveYearAvgDividendYield'
# GRVY 'freeCashflow'
# GTH 'overallRisk'
# GTH 'trailingPE'
# GTH 'pegRatio'
# GTH 'earningsGrowth'
# GTH 'dividendYield'
# GTH 'fiveYearAvgDividendYield'
# HCM 'trailingPE'
# HCM 'pegRatio'
# HCM 'earningsGrowth'
# HCM 'dividendYield'
# HCM 'fiveYearAvgDividendYield'
# HDB 'overallRisk'
# HDB 'enterpriseToEbitda'
# HDB 'fiveYearAvgDividendYield'
# HDB 'freeCashflow'
# HDB 'debtToEquity'
# HDB 'quickRatio'
# HDB 'currentRatio'
# HEPS 'overallRisk'
# HEPS 'trailingPE'
# HEPS 'pegRatio'
# HEPS 'bookValue'
# HEPS 'priceToBook'
# HEPS 'enterpriseToRevenue'
# HEPS 'enterpriseToEbitda'
# HEPS 'earningsGrowth'
# HEPS 'dividendYield'
# HEPS 'fiveYearAvgDividendYield'
# HEPS 'freeCashflow'
# HHR 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HHR?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# HIMX 'overallRisk'
# HIMX 'beta'
# HIMX 'enterpriseToRevenue'
# HIMX 'enterpriseToEbitda'
# HIMX 'earningsGrowth'
# HIMX 'revenueGrowth'
# HIMX 'fiveYearAvgDividendYield'
# HIMX 'freeCashflow'
# HIMX 'debtToEquity'
# HIMX 'returnOnAssets'
# HIMX 'returnOnEquity'
# HIMX 'quickRatio'
# HIMX 'currentRatio'
# HKD 'recommendationMean'
# HKD 'numberOfAnalystOpinions'
# HKD 'overallRisk'
# HKD 'beta'
# HKD 'forwardEps'
# HKD 'forwardPE'
# HKD 'pegRatio'
# HKD 'dividendYield'
# HKD 'fiveYearAvgDividendYield'
# HKD 'freeCashflow'
# HKD 'debtToEquity'
# HKD 'returnOnAssets'
# HKD 'returnOnEquity'
# HLG 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HLG?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# HLN 'recommendationMean'
# HLN 'numberOfAnalystOpinions'
# HLN 'beta'
# HLN 'forwardEps'
# HLN 'forwardPE'
# HLN 'pegRatio'
# HLN 'fiveYearAvgDividendYield'
# HLN# 'recommendationMean'
# HLN# 'numberOfAnalystOpinions'
# HLN# 'beta'
# HLN# 'forwardEps'
# HLN# 'forwardPE'
# HLN# 'pegRatio'
# HLN# 'fiveYearAvgDividendYield'
# HMC 'pegRatio'
# HMY 'beta'
# HMY 'trailingPE'
# HMY 'pegRatio'
# HMY 'payoutRatio'
# HMY 'fiveYearAvgDividendYield'
# HNP 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HNP?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# HSBC 'pegRatio'
# HSBC 'enterpriseToEbitda'
# HSBC 'fiveYearAvgDividendYield'
# HSBC 'freeCashflow'
# HSBC 'debtToEquity'
# HSBC 'quickRatio'
# HSBC 'currentRatio'
# HTHT 'overallRisk'
# HTHT 'trailingPE'
# HTHT 'earningsGrowth'
# HTHT 'dividendYield'
# HTHT 'fiveYearAvgDividendYield'
# HUIZ 'overallRisk'
# HUIZ 'trailingPE'
# HUIZ 'pegRatio'
# HUIZ 'dividendYield'
# HUIZ 'fiveYearAvgDividendYield'
# HUIZ 'freeCashflow'
# HUYA 'overallRisk'
# HUYA 'trailingPE'
# HUYA 'earningsGrowth'
# HUYA 'dividendYield'
# HUYA 'fiveYearAvgDividendYield'
# HUYA 'freeCashflow'
# HYW 'overallRisk'
# HYW 'pegRatio'
# HYW 'dividendYield'
# HYW 'fiveYearAvgDividendYield'
# HYW 'freeCashflow'
# IBA 'shortName'
# IBA 'sector'
# IBA 'industry'
# IBA 'recommendationMean'
# IBA 'numberOfAnalystOpinions'
# IBA 'overallRisk'
# IBA 'beta'
# IBA 'previousClose'
# IBA 'trailingEps'
# IBA 'forwardEps'
# IBA 'trailingPE'
# IBA 'forwardPE'
# IBA 'pegRatio'
# IBA 'bookValue'
# IBA 'priceToBook'
# IBA 'enterpriseToRevenue'
# IBA 'enterpriseToEbitda'
# IBA 'ebitdaMargins'
# IBA 'profitMargins'
# IBA 'earningsGrowth'
# IBA 'revenueGrowth'
# IBA 'dividendYield'
# IBA 'payoutRatio'
# IBA 'fiveYearAvgDividendYield'
# IBA 'enterpriseValue'
# IBA 'freeCashflow'
# IBA 'debtToEquity'
# IBA 'returnOnAssets'
# IBA 'returnOnEquity'
# IBA 'quickRatio'
# IBA 'currentRatio'
# IBN 'enterpriseToEbitda'
# IBN 'fiveYearAvgDividendYield'
# IBN 'freeCashflow'
# IBN 'debtToEquity'
# IBN 'quickRatio'
# IBN 'currentRatio'
# ICLK 'overallRisk'
# ICLK 'trailingPE'
# ICLK 'pegRatio'
# ICLK 'earningsGrowth'
# ICLK 'dividendYield'
# ICLK 'fiveYearAvgDividendYield'
# IH 'overallRisk'
# IH 'pegRatio'
# IH 'dividendYield'
# IH 'fiveYearAvgDividendYield'
# IH 'freeCashflow'
# IHG 'pegRatio'
# IHG 'priceToBook'
# IHG 'fiveYearAvgDividendYield'
# IHG 'debtToEquity'
# IHG 'returnOnEquity'
# IMAB 'overallRisk'
# IMAB 'trailingPE'
# IMAB 'pegRatio'
# IMAB 'earningsGrowth'
# IMAB 'revenueGrowth'
# IMAB 'dividendYield'
# IMAB 'fiveYearAvgDividendYield'
# IMAB 'freeCashflow'
# IMCR 'overallRisk'
# IMCR 'trailingPE'
# IMCR 'pegRatio'
# IMCR 'earningsGrowth'
# IMCR 'dividendYield'
# IMCR 'fiveYearAvgDividendYield'
# IMMP 'overallRisk'
# IMMP 'trailingPE'
# IMMP 'pegRatio'
# IMMP 'earningsGrowth'
# IMMP 'dividendYield'
# IMMP 'fiveYearAvgDividendYield'
# IMOS 'recommendationMean'
# IMOS 'numberOfAnalystOpinions'
# IMOS 'overallRisk'
# IMOS 'pegRatio'
# IMOS 'fiveYearAvgDividendYield'
# IMRN 'numberOfAnalystOpinions'
# IMRN 'overallRisk'
# IMRN 'forwardEps'
# IMRN 'trailingPE'
# IMRN 'forwardPE'
# IMRN 'pegRatio'
# IMRN 'earningsGrowth'
# IMRN 'dividendYield'
# IMRN 'fiveYearAvgDividendYield'
# ING 'beta'
# ING 'enterpriseToEbitda'
# ING 'earningsGrowth'
# ING 'fiveYearAvgDividendYield'
# ING 'freeCashflow'
# ING 'debtToEquity'
# ING 'quickRatio'
# ING 'currentRatio'
# IONR 'recommendationMean'
# IONR 'numberOfAnalystOpinions'
# IONR 'forwardEps'
# IONR 'trailingPE'
# IONR 'forwardPE'
# IONR 'pegRatio'
# IONR 'enterpriseToRevenue'
# IONR 'earningsGrowth'
# IONR 'revenueGrowth'
# IONR 'dividendYield'
# IONR 'fiveYearAvgDividendYield'
# IPHA 'trailingPE'
# IPHA 'pegRatio'
# IPHA 'earningsGrowth'
# IPHA 'dividendYield'
# IPHA 'fiveYearAvgDividendYield'
# IQ 'overallRisk'
# IQ 'dividendYield'
# IQ 'fiveYearAvgDividendYield'
# IRCP 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/IRCP?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# IRS 'overallRisk'
# IRS 'pegRatio'
# IRS 'earningsGrowth'
# IRS 'fiveYearAvgDividendYield'
# ITCB 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ITCB?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ITUB 'enterpriseToEbitda'
# ITUB 'freeCashflow'
# ITUB 'debtToEquity'
# ITUB 'quickRatio'
# ITUB 'currentRatio'
# IVA 'recommendationMean'
# IVA 'numberOfAnalystOpinions'
# IVA 'forwardEps'
# IVA 'trailingPE'
# IVA 'forwardPE'
# IVA 'pegRatio'
# IVA 'earningsGrowth'
# IVA 'dividendYield'
# IVA 'fiveYearAvgDividendYield'
# IX 'pegRatio'
# IXHL 'recommendationMean'
# IXHL 'numberOfAnalystOpinions'
# IXHL 'forwardEps'
# IXHL 'trailingPE'
# IXHL 'forwardPE'
# IXHL 'pegRatio'
# IXHL 'enterpriseToEbitda'
# IXHL 'earningsGrowth'
# IXHL 'revenueGrowth'
# IXHL 'dividendYield'
# IXHL 'fiveYearAvgDividendYield'
# JD 'earningsGrowth'
# JD 'fiveYearAvgDividendYield'
# JFIN 'numberOfAnalystOpinions'
# JFIN 'overallRisk'
# JFIN 'pegRatio'
# JFIN 'fiveYearAvgDividendYield'
# JFIN 'freeCashflow'
# JFU 'numberOfAnalystOpinions'
# JFU 'overallRisk'
# JFU 'forwardEps'
# JFU 'trailingPE'
# JFU 'forwardPE'
# JFU 'pegRatio'
# JFU 'earningsGrowth'
# JFU 'dividendYield'
# JFU 'fiveYearAvgDividendYield'
# JG 'overallRisk'
# JG 'trailingPE'
# JG 'pegRatio'
# JG 'earningsGrowth'
# JG 'dividendYield'
# JG 'fiveYearAvgDividendYield'
# JG 'freeCashflow'
# JHX 'pegRatio'
# JHX 'dividendYield'
# JHX 'fiveYearAvgDividendYield'
# JKS 'overallRisk'
# JKS 'dividendYield'
# JKS 'fiveYearAvgDividendYield'
# JKS 'freeCashflow'
# JMIA 'overallRisk'
# JMIA 'beta'
# JMIA 'trailingPE'
# JMIA 'pegRatio'
# JMIA 'enterpriseToRevenue'
# JMIA 'enterpriseToEbitda'
# JMIA 'earningsGrowth'
# JMIA 'revenueGrowth'
# JMIA 'dividendYield'
# JMIA 'fiveYearAvgDividendYield'
# JMIA 'freeCashflow'
# JMIA 'debtToEquity'
# JMIA 'returnOnAssets'
# JMIA 'returnOnEquity'
# JMIA 'quickRatio'
# JMIA 'currentRatio'
# JP 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/JP?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# JT 'numberOfAnalystOpinions'
# JT 'overallRisk'
# JT 'trailingPE'
# JT 'pegRatio'
# JT 'earningsGrowth'
# JT 'dividendYield'
# JT 'fiveYearAvgDividendYield'
# JT 'freeCashflow'
# KB 'enterpriseToEbitda'
# KB 'freeCashflow'
# KB 'debtToEquity'
# KB 'quickRatio'
# KB 'currentRatio'
# KC 'overallRisk'
# KC 'trailingPE'
# KC 'pegRatio'
# KC 'earningsGrowth'
# KC 'dividendYield'
# KC 'fiveYearAvgDividendYield'
# KEP 'trailingPE'
# KEP 'pegRatio'
# KEP 'enterpriseToEbitda'
# KEP 'earningsGrowth'
# KEP 'revenueGrowth'
# KEP 'dividendYield'
# KEP 'fiveYearAvgDividendYield'
# KEP 'freeCashflow'
# KEP 'debtToEquity'
# KEP 'returnOnAssets'
# KEP 'returnOnEquity'
# KEP 'quickRatio'
# KEP 'currentRatio'
# KOF 'overallRisk'
# KRKR 'overallRisk'
# KRKR 'trailingPE'
# KRKR 'pegRatio'
# KRKR 'earningsGrowth'
# KRKR 'dividendYield'
# KRKR 'fiveYearAvgDividendYield'
# KRKR 'freeCashflow'
# KT 'pegRatio'
# KT 'earningsGrowth'
# KT 'dividendYield'
# KT 'fiveYearAvgDividendYield'
# KT 'freeCashflow'
# KUKE 'recommendationMean'
# KUKE 'numberOfAnalystOpinions'
# KUKE 'overallRisk'
# KUKE 'forwardEps'
# KUKE 'trailingPE'
# KUKE 'forwardPE'
# KUKE 'pegRatio'
# KUKE 'earningsGrowth'
# KUKE 'dividendYield'
# KUKE 'fiveYearAvgDividendYield'
# KZIA 'overallRisk'
# KZIA 'forwardEps'
# KZIA 'trailingPE'
# KZIA 'forwardPE'
# KZIA 'pegRatio'
# KZIA 'enterpriseToRevenue'
# KZIA 'earningsGrowth'
# KZIA 'dividendYield'
# KZIA 'fiveYearAvgDividendYield'
# LBPS 'shortName'
# LBPS 'sector'
# LBPS 'industry'
# LBPS 'recommendationMean'
# LBPS 'numberOfAnalystOpinions'
# LBPS 'overallRisk'
# LBPS 'beta'
# LBPS 'previousClose'
# LBPS 'trailingEps'
# LBPS 'forwardEps'
# LBPS 'trailingPE'
# LBPS 'forwardPE'
# LBPS 'pegRatio'
# LBPS 'bookValue'
# LBPS 'priceToBook'
# LBPS 'enterpriseToRevenue'
# LBPS 'enterpriseToEbitda'
# LBPS 'ebitdaMargins'
# LBPS 'profitMargins'
# LBPS 'earningsGrowth'
# LBPS 'revenueGrowth'
# LBPS 'dividendYield'
# LBPS 'payoutRatio'
# LBPS 'fiveYearAvgDividendYield'
# LBPS 'enterpriseValue'
# LBPS 'freeCashflow'
# LBPS 'debtToEquity'
# LBPS 'returnOnAssets'
# LBPS 'returnOnEquity'
# LBPS 'quickRatio'
# LBPS 'currentRatio'
# LEGN 'overallRisk'
# LEGN 'beta'
# LEGN 'trailingPE'
# LEGN 'pegRatio'
# LEGN 'enterpriseToRevenue'
# LEGN 'enterpriseToEbitda'
# LEGN 'earningsGrowth'
# LEGN 'revenueGrowth'
# LEGN 'dividendYield'
# LEGN 'fiveYearAvgDividendYield'
# LEGN 'freeCashflow'
# LEGN 'debtToEquity'
# LEGN 'returnOnAssets'
# LEGN 'returnOnEquity'
# LEGN 'quickRatio'
# LEGN 'currentRatio'
# LEJU 'numberOfAnalystOpinions'
# LEJU 'overallRisk'
# LEJU 'trailingPE'
# LEJU 'pegRatio'
# LEJU 'earningsGrowth'
# LEJU 'dividendYield'
# LEJU 'fiveYearAvgDividendYield'
# LEJU 'freeCashflow'
# LFC 'shortName'
# LFC 'sector'
# LFC 'industry'
# LFC 'recommendationMean'
# LFC 'numberOfAnalystOpinions'
# LFC 'overallRisk'
# LFC 'beta'
# LFC 'previousClose'
# LFC 'trailingEps'
# LFC 'forwardEps'
# LFC 'trailingPE'
# LFC 'forwardPE'
# LFC 'pegRatio'
# LFC 'bookValue'
# LFC 'priceToBook'
# LFC 'enterpriseToRevenue'
# LFC 'enterpriseToEbitda'
# LFC 'ebitdaMargins'
# LFC 'profitMargins'
# LFC 'earningsGrowth'
# LFC 'revenueGrowth'
# LFC 'dividendYield'
# LFC 'payoutRatio'
# LFC 'fiveYearAvgDividendYield'
# LFC 'enterpriseValue'
# LFC 'freeCashflow'
# LFC 'debtToEquity'
# LFC 'returnOnAssets'
# LFC 'returnOnEquity'
# LFC 'quickRatio'
# LFC 'currentRatio'
# LGHL 'recommendationMean'
# LGHL 'numberOfAnalystOpinions'
# LGHL 'overallRisk'
# LGHL 'forwardEps'
# LGHL 'trailingPE'
# LGHL 'forwardPE'
# LGHL 'pegRatio'
# LGHL 'enterpriseToEbitda'
# LGHL 'earningsGrowth'
# LGHL 'dividendYield'
# LGHL 'fiveYearAvgDividendYield'
# LGHL 'freeCashflow'
# LI 'overallRisk'
# LI 'trailingPE'
# LI 'earningsGrowth'
# LI 'dividendYield'
# LI 'fiveYearAvgDividendYield'
# LIAN 'overallRisk'
# LIAN 'beta'
# LIAN 'trailingPE'
# LIAN 'enterpriseToRevenue'
# LIAN 'enterpriseToEbitda'
# LIAN 'earningsGrowth'
# LIAN 'revenueGrowth'
# LIAN 'dividendYield'
# LIAN 'fiveYearAvgDividendYield'
# LIAN 'freeCashflow'
# LIAN 'debtToEquity'
# LIAN 'returnOnAssets'
# LIAN 'returnOnEquity'
# LIAN 'quickRatio'
# LIAN 'currentRatio'
# LITB 'recommendationMean'
# LITB 'numberOfAnalystOpinions'
# LITB 'overallRisk'
# LITB 'trailingPE'
# LITB 'pegRatio'
# LITB 'earningsGrowth'
# LITB 'dividendYield'
# LITB 'fiveYearAvgDividendYield'
# LITB 'freeCashflow'
# LIZI 'overallRisk'
# LIZI 'pegRatio'
# LIZI 'dividendYield'
# LIZI 'fiveYearAvgDividendYield'
# LIZI 'freeCashflow'
# LND 'recommendationMean'
# LND 'numberOfAnalystOpinions'
# LND 'overallRisk'
# LND 'forwardEps'
# LND 'forwardPE'
# LND 'pegRatio'
# LND 'earningsGrowth'
# LOMA 'overallRisk'
# LOMA 'payoutRatio'
# LOMA 'fiveYearAvgDividendYield'
# LOV 'overallRisk'
# LOV 'beta'
# LOV 'trailingPE'
# LOV 'pegRatio'
# LOV 'priceToBook'
# LOV 'enterpriseToRevenue'
# LOV 'enterpriseToEbitda'
# LOV 'earningsGrowth'
# LOV 'revenueGrowth'
# LOV 'dividendYield'
# LOV 'fiveYearAvgDividendYield'
# LOV 'freeCashflow'
# LOV 'debtToEquity'
# LOV 'returnOnAssets'
# LOV 'returnOnEquity'
# LOV 'quickRatio'
# LOV 'currentRatio'
# LPL 'trailingPE'
# LPL 'earningsGrowth'
# LPL 'dividendYield'
# LPL 'fiveYearAvgDividendYield'
# LU 'overallRisk'
# LU 'fiveYearAvgDividendYield'
# LX 'overallRisk'
# LX 'pegRatio'
# LX 'dividendYield'
# LX 'fiveYearAvgDividendYield'
# LX 'freeCashflow'
# LXEH 'recommendationMean'
# LXEH 'numberOfAnalystOpinions'
# LXEH 'overallRisk'
# LXEH 'forwardEps'
# LXEH 'trailingPE'
# LXEH 'forwardPE'
# LXEH 'pegRatio'
# LXEH 'earningsGrowth'
# LXEH 'dividendYield'
# LXEH 'fiveYearAvgDividendYield'
# LYG 'forwardPE'
# LYG 'pegRatio'
# LYG 'enterpriseToEbitda'
# LYG 'fiveYearAvgDividendYield'
# LYG 'freeCashflow'
# LYG 'debtToEquity'
# LYG 'quickRatio'
# LYG 'currentRatio'
# MBT 'shortName'
# MBT 'sector'
# MBT 'industry'
# MBT 'recommendationMean'
# MBT 'numberOfAnalystOpinions'
# MBT 'overallRisk'
# MBT 'beta'
# MBT 'previousClose'
# MBT 'trailingEps'
# MBT 'forwardEps'
# MBT 'trailingPE'
# MBT 'forwardPE'
# MBT 'pegRatio'
# MBT 'bookValue'
# MBT 'priceToBook'
# MBT 'enterpriseToRevenue'
# MBT 'enterpriseToEbitda'
# MBT 'ebitdaMargins'
# MBT 'profitMargins'
# MBT 'earningsGrowth'
# MBT 'revenueGrowth'
# MBT 'dividendYield'
# MBT 'payoutRatio'
# MBT 'fiveYearAvgDividendYield'
# MBT 'enterpriseValue'
# MBT 'freeCashflow'
# MBT 'debtToEquity'
# MBT 'returnOnAssets'
# MBT 'returnOnEquity'
# MBT 'quickRatio'
# MBT 'currentRatio'
# MDGS 'recommendationMean'
# MDGS 'numberOfAnalystOpinions'
# MDGS 'overallRisk'
# MDGS 'forwardEps'
# MDGS 'trailingPE'
# MDGS 'forwardPE'
# MDGS 'pegRatio'
# MDGS 'earningsGrowth'
# MDGS 'payoutRatio'
# MDGS 'fiveYearAvgDividendYield'
# MDXH 'trailingPE'
# MDXH 'pegRatio'
# MDXH 'earningsGrowth'
# MDXH 'dividendYield'
# MDXH 'fiveYearAvgDividendYield'
# MDXH 'freeCashflow'
# MDXH 'returnOnAssets'
# MESO 'earningsGrowth'
# MESO 'dividendYield'
# MESO 'fiveYearAvgDividendYield'
# MF 'overallRisk'
# MF 'pegRatio'
# MF 'priceToBook'
# MF 'earningsGrowth'
# MF 'dividendYield'
# MF 'fiveYearAvgDividendYield'
# MF 'debtToEquity'
# MF 'returnOnEquity'
# MFG 'enterpriseToEbitda'
# MFG 'freeCashflow'
# MFG 'debtToEquity'
# MFG 'quickRatio'
# MFG 'currentRatio'
# MFGP 'shortName'
# MFGP 'sector'
# MFGP 'industry'
# MFGP 'recommendationMean'
# MFGP 'numberOfAnalystOpinions'
# MFGP 'overallRisk'
# MFGP 'beta'
# MFGP 'previousClose'
# MFGP 'trailingEps'
# MFGP 'forwardEps'
# MFGP 'trailingPE'
# MFGP 'forwardPE'
# MFGP 'pegRatio'
# MFGP 'bookValue'
# MFGP 'priceToBook'
# MFGP 'enterpriseToRevenue'
# MFGP 'enterpriseToEbitda'
# MFGP 'ebitdaMargins'
# MFGP 'profitMargins'
# MFGP 'earningsGrowth'
# MFGP 'revenueGrowth'
# MFGP 'dividendYield'
# MFGP 'payoutRatio'
# MFGP 'fiveYearAvgDividendYield'
# MFGP 'enterpriseValue'
# MFGP 'freeCashflow'
# MFGP 'debtToEquity'
# MFGP 'returnOnAssets'
# MFGP 'returnOnEquity'
# MFGP 'quickRatio'
# MFGP 'currentRatio'
# MFH 'recommendationMean'
# MFH 'numberOfAnalystOpinions'
# MFH 'overallRisk'
# MFH 'beta'
# MFH 'forwardEps'
# MFH 'trailingPE'
# MFH 'forwardPE'
# MFH 'pegRatio'
# MFH 'earningsGrowth'
# MFH 'dividendYield'
# MFH 'fiveYearAvgDividendYield'
# MITC 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/MITC?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# MITO 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/MITO?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# MIXT 'overallRisk'
# MLCO 'overallRisk'
# MLCO 'trailingPE'
# MLCO 'priceToBook'
# MLCO 'earningsGrowth'
# MLCO 'dividendYield'
# MLCO 'fiveYearAvgDividendYield'
# MLCO 'freeCashflow'
# MLCO 'debtToEquity'
# MLCO 'returnOnEquity'
# MNSO 'overallRisk'
# MNSO 'dividendYield'
# MNSO 'fiveYearAvgDividendYield'
# MNSO 'freeCashflow'
# MOGU 'numberOfAnalystOpinions'
# MOGU 'overallRisk'
# MOGU 'trailingPE'
# MOGU 'pegRatio'
# MOGU 'earningsGrowth'
# MOGU 'dividendYield'
# MOGU 'fiveYearAvgDividendYield'
# MOHO 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/MOHO?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# MOLN 'overallRisk'
# MOLN 'trailingPE'
# MOLN 'pegRatio'
# MOLN 'earningsGrowth'
# MOLN 'dividendYield'
# MOLN 'fiveYearAvgDividendYield'
# MOMO 'overallRisk'
# MOMO 'dividendYield'
# MOMO 'fiveYearAvgDividendYield'
# MOR 'beta'
# MOR 'trailingPE'
# MOR 'pegRatio'
# MOR 'earningsGrowth'
# MOR 'dividendYield'
# MOR 'fiveYearAvgDividendYield'
# MOR 'freeCashflow'
# MOR 'returnOnAssets'
# MOR 'returnOnEquity'
# MOR 'quickRatio'
# MOR 'currentRatio'
# MREO 'overallRisk'
# MREO 'trailingPE'
# MREO 'pegRatio'
# MREO 'enterpriseToRevenue'
# MREO 'earningsGrowth'
# MREO 'revenueGrowth'
# MREO 'dividendYield'
# MREO 'fiveYearAvgDividendYield'
# MRM 'recommendationMean'
# MRM 'numberOfAnalystOpinions'
# MRM 'overallRisk'
# MRM 'forwardEps'
# MRM 'forwardPE'
# MRM 'pegRatio'
# MRM 'priceToBook'
# MRM 'earningsGrowth'
# MRM 'dividendYield'
# MRM 'fiveYearAvgDividendYield'
# MRM 'debtToEquity'
# MRM 'returnOnEquity'
# MSC 'overallRisk'
# MSC 'trailingPE'
# MSC 'pegRatio'
# MSC 'earningsGrowth'
# MSC 'revenueGrowth'
# MSC 'dividendYield'
# MSC 'fiveYearAvgDividendYield'
# MSC 'freeCashflow'
# MT 'fiveYearAvgDividendYield'
# MTL 'shortName'
# MTL 'sector'
# MTL 'industry'
# MTL 'recommendationMean'
# MTL 'numberOfAnalystOpinions'
# MTL 'overallRisk'
# MTL 'beta'
# MTL 'previousClose'
# MTL 'trailingEps'
# MTL 'forwardEps'
# MTL 'trailingPE'
# MTL 'forwardPE'
# MTL 'pegRatio'
# MTL 'bookValue'
# MTL 'priceToBook'
# MTL 'enterpriseToRevenue'
# MTL 'enterpriseToEbitda'
# MTL 'ebitdaMargins'
# MTL 'profitMargins'
# MTL 'earningsGrowth'
# MTL 'revenueGrowth'
# MTL 'dividendYield'
# MTL 'payoutRatio'
# MTL 'fiveYearAvgDividendYield'
# MTL 'enterpriseValue'
# MTL 'freeCashflow'
# MTL 'debtToEquity'
# MTL 'returnOnAssets'
# MTL 'returnOnEquity'
# MTL 'quickRatio'
# MTL 'currentRatio'
# MTLS 'overallRisk'
# MTLS 'earningsGrowth'
# MTLS 'dividendYield'
# MTLS 'fiveYearAvgDividendYield'
# MTP 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/MTP?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# MUFG 'enterpriseToEbitda'
# MUFG 'freeCashflow'
# MUFG 'debtToEquity'
# MUFG 'returnOnAssets'
# MUFG 'returnOnEquity'
# MUFG 'quickRatio'
# MUFG 'currentRatio'
# MYNA 'overallRisk'
# MYNA 'forwardEps'
# MYNA 'trailingPE'
# MYNA 'forwardPE'
# MYNA 'pegRatio'
# MYNA 'earningsGrowth'
# MYNA 'revenueGrowth'
# MYNA 'dividendYield'
# MYNA 'fiveYearAvgDividendYield'
# MYTE 'overallRisk'
# MYTE 'trailingPE'
# MYTE 'earningsGrowth'
# MYTE 'dividendYield'
# MYTE 'fiveYearAvgDividendYield'
# NA 'recommendationMean'
# NA 'numberOfAnalystOpinions'
# NA 'overallRisk'
# NA 'beta'
# NA 'forwardEps'
# NA 'forwardPE'
# NA 'pegRatio'
# NA 'enterpriseToRevenue'
# NA 'enterpriseToEbitda'
# NA 'earningsGrowth'
# NA 'revenueGrowth'
# NA 'dividendYield'
# NA 'fiveYearAvgDividendYield'
# NA 'freeCashflow'
# NA 'debtToEquity'
# NA 'returnOnAssets'
# NA 'returnOnEquity'
# NA 'quickRatio'
# NA 'currentRatio'
# NAAS 'numberOfAnalystOpinions'
# NAAS 'overallRisk'
# NAAS 'beta'
# NAAS 'trailingPE'
# NAAS 'pegRatio'
# NAAS 'earningsGrowth'
# NAAS 'dividendYield'
# NAAS 'fiveYearAvgDividendYield'
# NAAS 'freeCashflow'
# NAAS 'returnOnAssets'
# NBTX 'trailingPE'
# NBTX 'pegRatio'
# NBTX 'priceToBook'
# NBTX 'earningsGrowth'
# NBTX 'dividendYield'
# NBTX 'fiveYearAvgDividendYield'
# NBTX 'debtToEquity'
# NBTX 'returnOnEquity'
# NCNA 'overallRisk'
# NCNA 'trailingPE'
# NCNA 'pegRatio'
# NCNA 'enterpriseToRevenue'
# NCNA 'earningsGrowth'
# NCNA 'revenueGrowth'
# NCNA 'dividendYield'
# NCNA 'fiveYearAvgDividendYield'
# NCTY 'recommendationMean'
# NCTY 'numberOfAnalystOpinions'
# NCTY 'overallRisk'
# NCTY 'forwardEps'
# NCTY 'trailingPE'
# NCTY 'forwardPE'
# NCTY 'pegRatio'
# NCTY 'earningsGrowth'
# NCTY 'dividendYield'
# NCTY 'fiveYearAvgDividendYield'
# NGG 'pegRatio'
# NICE 'overallRisk'
# NICE 'dividendYield'
# NICE 'fiveYearAvgDividendYield'
# NIO 'recommendationMean'
# NIO 'numberOfAnalystOpinions'
# NIO 'overallRisk'
# NIO 'trailingPE'
# NIO 'pegRatio'
# NIO 'earningsGrowth'
# NIO 'dividendYield'
# NIO 'fiveYearAvgDividendYield'
# NIO 'freeCashflow'
# NIU 'overallRisk'
# NIU 'trailingPE'
# NIU 'earningsGrowth'
# NIU 'dividendYield'
# NIU 'fiveYearAvgDividendYield'
# NIU 'freeCashflow'
# NMR 'recommendationMean'
# NMR 'forwardEps'
# NMR 'forwardPE'
# NMR 'pegRatio'
# NMR 'enterpriseToEbitda'
# NMR 'dividendYield'
# NMR 'fiveYearAvgDividendYield'
# NMR 'freeCashflow'
# NNDM 'numberOfAnalystOpinions'
# NNDM 'overallRisk'
# NNDM 'trailingPE'
# NNDM 'pegRatio'
# NNDM 'earningsGrowth'
# NNDM 'dividendYield'
# NNDM 'fiveYearAvgDividendYield'
# NOAH 'overallRisk'
# NOAH 'fiveYearAvgDividendYield'
# NOAH 'freeCashflow'
# NOK 'fiveYearAvgDividendYield'
# NTCO 'beta'
# NTCO 'trailingPE'
# NTCO 'enterpriseToRevenue'
# NTCO 'enterpriseToEbitda'
# NTCO 'earningsGrowth'
# ...
# SUPV 'trailingPE'
# SUPV 'enterpriseToEbitda'
# SUPV 'earningsGrowth'
# SUPV 'dividendYield'
# SUPV 'fiveYearAvgDividendYield'
# SUPV 'freeCashflow'
# SUPV 'debtToEquity'
# SUPV 'quickRatio'
# SUPV 'currentRatio'
# SUZ 'fiveYearAvgDividendYield'
# SY 'overallRisk'
# SY 'trailingPE'
# SY 'earningsGrowth'
# SY 'dividendYield'
# SY 'fiveYearAvgDividendYield'
# SY 'freeCashflow'
# Symbol 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/SYMBOL?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# TAK 'pegRatio'
# TAL 'overallRisk'
# TAL 'trailingPE'
# TAL 'earningsGrowth'
# TAL 'dividendYield'
# TAL 'fiveYearAvgDividendYield'
# TC 'numberOfAnalystOpinions'
# TC 'overallRisk'
# TC 'trailingPE'
# TC 'pegRatio'
# TC 'earningsGrowth'
# TC 'dividendYield'
# TC 'fiveYearAvgDividendYield'
# TCOM 'overallRisk'
# TCOM 'earningsGrowth'
# TCOM 'dividendYield'
# TCOM 'fiveYearAvgDividendYield'
# TCOM 'freeCashflow'
# TDCX 'overallRisk'
# TDCX 'beta'
# TDCX 'dividendYield'
# TDCX 'fiveYearAvgDividendYield'
# TEDU 'overallRisk'
# TEDU 'priceToBook'
# TEDU 'earningsGrowth'
# TEDU 'dividendYield'
# TEDU 'fiveYearAvgDividendYield'
# TEDU 'freeCashflow'
# TEDU 'debtToEquity'
# TEDU 'returnOnEquity'
# TEF 'pegRatio'
# TEO 'overallRisk'
# TEO 'trailingPE'
# TEO 'payoutRatio'
# TEVA 'trailingPE'
# TEVA 'earningsGrowth'
# TEVA 'dividendYield'
# TEVA 'fiveYearAvgDividendYield'
# TGS 'overallRisk'
# TGS 'pegRatio'
# TGS 'dividendYield'
# TGS 'fiveYearAvgDividendYield'
# TIGR 'overallRisk'
# TIGR 'pegRatio'
# TIGR 'enterpriseToEbitda'
# TIGR 'earningsGrowth'
# TIGR 'dividendYield'
# TIGR 'fiveYearAvgDividendYield'
# TIGR 'freeCashflow'
# TIMB 'overallRisk'
# TIMB 'fiveYearAvgDividendYield'
# TKC 'overallRisk'
# TKC 'enterpriseToRevenue'
# TKC 'enterpriseToEbitda'
# TKC 'dividendYield'
# TKC 'freeCashflow'
# TLK 'overallRisk'
# TLK 'pegRatio'
# TLK 'enterpriseToRevenue'
# TLK 'enterpriseToEbitda'
# TLK 'fiveYearAvgDividendYield'
# TLK 'freeCashflow'
# TLSA 'overallRisk'
# TLSA 'beta'
# TLSA 'trailingPE'
# TLSA 'pegRatio'
# TLSA 'enterpriseToRevenue'
# TLSA 'earningsGrowth'
# TLSA 'revenueGrowth'
# TLSA 'dividendYield'
# TLSA 'fiveYearAvgDividendYield'
# TM 'pegRatio'
# TME 'overallRisk'
# TME 'beta'
# TME 'enterpriseToRevenue'
# TME 'enterpriseToEbitda'
# TME 'earningsGrowth'
# TME 'revenueGrowth'
# TME 'dividendYield'
# TME 'fiveYearAvgDividendYield'
# TME 'freeCashflow'
# TME 'debtToEquity'
# TME 'returnOnAssets'
# TME 'returnOnEquity'
# TME 'quickRatio'
# TME 'currentRatio'
# TOUR 'overallRisk'
# TOUR 'trailingPE'
# TOUR 'earningsGrowth'
# TOUR 'dividendYield'
# TOUR 'fiveYearAvgDividendYield'
# TOUR 'freeCashflow'
# TRIB 'recommendationMean'
# TRIB 'numberOfAnalystOpinions'
# TRIB 'overallRisk'
# TRIB 'trailingPE'
# TRIB 'priceToBook'
# TRIB 'earningsGrowth'
# TRIB 'dividendYield'
# TRIB 'fiveYearAvgDividendYield'
# TRIB 'debtToEquity'
# TRIB 'returnOnEquity'
# TRMR 'overallRisk'
# TRMR 'trailingPE'
# TRMR 'pegRatio'
# TRMR 'earningsGrowth'
# TRMR 'dividendYield'
# TRMR 'fiveYearAvgDividendYield'
# TRVG 'overallRisk'
# TRVG 'trailingPE'
# TRVG 'earningsGrowth'
# TRVG 'dividendYield'
# TRVG 'fiveYearAvgDividendYield'
# TSM 'overallRisk'
# TTM 'shortName'
# TTM 'sector'
# TTM 'industry'
# TTM 'recommendationMean'
# TTM 'numberOfAnalystOpinions'
# TTM 'overallRisk'
# TTM 'beta'
# TTM 'previousClose'
# TTM 'trailingEps'
# TTM 'forwardEps'
# TTM 'trailingPE'
# TTM 'forwardPE'
# TTM 'pegRatio'
# TTM 'bookValue'
# TTM 'priceToBook'
# TTM 'enterpriseToRevenue'
# TTM 'enterpriseToEbitda'
# TTM 'ebitdaMargins'
# TTM 'profitMargins'
# TTM 'earningsGrowth'
# TTM 'revenueGrowth'
# TTM 'dividendYield'
# TTM 'payoutRatio'
# TTM 'fiveYearAvgDividendYield'
# TTM 'enterpriseValue'
# TTM 'freeCashflow'
# TTM 'debtToEquity'
# TTM 'returnOnAssets'
# TTM 'returnOnEquity'
# TTM 'quickRatio'
# TTM 'currentRatio'
# TUYA 'overallRisk'
# TUYA 'trailingPE'
# TUYA 'earningsGrowth'
# TUYA 'dividendYield'
# TUYA 'fiveYearAvgDividendYield'
# TV 'overallRisk'
# TV 'trailingPE'
# TV 'payoutRatio'
# TV 'fiveYearAvgDividendYield'
# TX 'fiveYearAvgDividendYield'
# UBS 'enterpriseToEbitda'
# UBS 'freeCashflow'
# UBS 'debtToEquity'
# UBS 'quickRatio'
# UBS 'currentRatio'
# UCL 'overallRisk'
# UCL 'beta'
# UCL 'trailingPE'
# UCL 'pegRatio'
# UCL 'enterpriseToRevenue'
# UCL 'enterpriseToEbitda'
# UCL 'earningsGrowth'
# UCL 'revenueGrowth'
# UCL 'dividendYield'
# UCL 'fiveYearAvgDividendYield'
# UCL 'freeCashflow'
# UCL 'debtToEquity'
# UCL 'returnOnAssets'
# UCL 'returnOnEquity'
# UCL 'quickRatio'
# UCL 'currentRatio'
# UL 'pegRatio'
# UMC 'overallRisk'
# UXIN 'overallRisk'
# UXIN 'trailingPE'
# UXIN 'pegRatio'
# UXIN 'priceToBook'
# UXIN 'enterpriseToRevenue'
# UXIN 'enterpriseToEbitda'
# UXIN 'earningsGrowth'
# UXIN 'revenueGrowth'
# UXIN 'dividendYield'
# UXIN 'fiveYearAvgDividendYield'
# UXIN 'enterpriseValue'
# UXIN 'freeCashflow'
# UXIN 'debtToEquity'
# UXIN 'returnOnAssets'
# UXIN 'returnOnEquity'
# UXIN 'quickRatio'
# UXIN 'currentRatio'
# VACC 'overallRisk'
# VACC 'trailingPE'
# VACC 'pegRatio'
# VACC 'earningsGrowth'
# VACC 'dividendYield'
# VACC 'fiveYearAvgDividendYield'
# VALE 'fiveYearAvgDividendYield'
# VALN 'trailingPE'
# VALN 'pegRatio'
# VALN 'earningsGrowth'
# VALN 'dividendYield'
# VALN 'fiveYearAvgDividendYield'
# VEON 'numberOfAnalystOpinions'
# VEON 'overallRisk'
# VEON 'pegRatio'
# VEON 'earningsGrowth'
# VEON 'dividendYield'
# VEON 'fiveYearAvgDividendYield'
# VIAO 'overallRisk'
# VIAO 'trailingPE'
# VIAO 'pegRatio'
# VIAO 'earningsGrowth'
# VIAO 'dividendYield'
# VIAO 'fiveYearAvgDividendYield'
# VIAO 'freeCashflow'
# VIOT 'numberOfAnalystOpinions'
# VIOT 'overallRisk'
# VIOT 'trailingPE'
# VIOT 'pegRatio'
# VIOT 'earningsGrowth'
# VIOT 'dividendYield'
# VIOT 'fiveYearAvgDividendYield'
# VIPS 'overallRisk'
# VIPS 'dividendYield'
# VIPS 'fiveYearAvgDividendYield'
# VIPS 'freeCashflow'
# VIST 'overallRisk'
# VIST 'pegRatio'
# VIST 'dividendYield'
# VIST 'fiveYearAvgDividendYield'
# VJET 'overallRisk'
# VJET 'trailingPE'
# VJET 'pegRatio'
# VJET 'earningsGrowth'
# VJET 'dividendYield'
# VJET 'fiveYearAvgDividendYield'
# VLRS 'overallRisk'
# VLRS 'trailingPE'
# VLRS 'earningsGrowth'
# VLRS 'dividendYield'
# VLRS 'fiveYearAvgDividendYield'
# VNET 'overallRisk'
# VNET 'trailingPE'
# VNET 'dividendYield'
# VNET 'fiveYearAvgDividendYield'
# VOD 'pegRatio'
# VRNA 'overallRisk'
# VRNA 'trailingPE'
# VRNA 'pegRatio'
# VRNA 'earningsGrowth'
# VRNA 'revenueGrowth'
# VRNA 'dividendYield'
# VRNA 'fiveYearAvgDividendYield'
# WAVE 'recommendationMean'
# WAVE 'numberOfAnalystOpinions'
# WAVE 'overallRisk'
# WAVE 'forwardEps'
# WAVE 'trailingPE'
# WAVE 'forwardPE'
# WAVE 'pegRatio'
# WAVE 'enterpriseToRevenue'
# WAVE 'earningsGrowth'
# WAVE 'revenueGrowth'
# WAVE 'dividendYield'
# WAVE 'fiveYearAvgDividendYield'
# WAVE 'freeCashflow'
# WB 'overallRisk'
# WB 'earningsGrowth'
# WB 'dividendYield'
# WB 'fiveYearAvgDividendYield'
# WB 'freeCashflow'
# WDH 'overallRisk'
# WDH 'pegRatio'
# WDH 'dividendYield'
# WDH 'fiveYearAvgDividendYield'
# WDH 'freeCashflow'
# WDS 'recommendationMean'
# WDS 'numberOfAnalystOpinions'
# WDS 'forwardEps'
# WDS 'forwardPE'
# WDS 'pegRatio'
# WF 'overallRisk'
# WF 'enterpriseToEbitda'
# WF 'fiveYearAvgDividendYield'
# WF 'freeCashflow'
# WF 'debtToEquity'
# WF 'quickRatio'
# WF 'currentRatio'
# WIMI 'numberOfAnalystOpinions'
# WIMI 'overallRisk'
# WIMI 'trailingPE'
# WIMI 'pegRatio'
# WIMI 'earningsGrowth'
# WIMI 'dividendYield'
# WIMI 'fiveYearAvgDividendYield'
# WKEY 'overallRisk'
# WKEY 'forwardEps'
# WKEY 'trailingPE'
# WKEY 'forwardPE'
# WKEY 'pegRatio'
# WKEY 'earningsGrowth'
# WKEY 'dividendYield'
# WKEY 'fiveYearAvgDividendYield'
# WNS 'overallRisk'
# WNS 'dividendYield'
# WNS 'fiveYearAvgDividendYield'
# WPP 'forwardEps'
# WPP 'forwardPE'
# WPP 'pegRatio'
# XIN 'numberOfAnalystOpinions'
# XIN 'overallRisk'
# XIN 'trailingPE'
# XIN 'pegRatio'
# XIN 'priceToBook'
# XIN 'earningsGrowth'
# XIN 'dividendYield'
# XIN 'fiveYearAvgDividendYield'
# XNET 'recommendationMean'
# XNET 'numberOfAnalystOpinions'
# XNET 'overallRisk'
# XNET 'beta'
# XNET 'forwardEps'
# XNET 'forwardPE'
# XNET 'pegRatio'
# XNET 'enterpriseToRevenue'
# XNET 'enterpriseToEbitda'
# XNET 'earningsGrowth'
# XNET 'revenueGrowth'
# XNET 'dividendYield'
# XNET 'fiveYearAvgDividendYield'
# XNET 'freeCashflow'
# XNET 'debtToEquity'
# XNET 'returnOnAssets'
# XNET 'returnOnEquity'
# XNET 'quickRatio'
# XNET 'currentRatio'
# XPEV 'trailingPE'
# XPEV 'earningsGrowth'
# XPEV 'dividendYield'
# XPEV 'fiveYearAvgDividendYield'
# XPEV 'freeCashflow'
# XTLB 'recommendationMean'
# XTLB 'numberOfAnalystOpinions'
# XTLB 'overallRisk'
# XTLB 'beta'
# XTLB 'forwardEps'
# XTLB 'trailingPE'
# XTLB 'forwardPE'
# XTLB 'pegRatio'
# XTLB 'enterpriseToRevenue'
# XTLB 'enterpriseToEbitda'
# XTLB 'earningsGrowth'
# XTLB 'revenueGrowth'
# XTLB 'dividendYield'
# XTLB 'fiveYearAvgDividendYield'
# XTLB 'freeCashflow'
# XTLB 'debtToEquity'
# XTLB 'returnOnAssets'
# XTLB 'returnOnEquity'
# XTLB 'quickRatio'
# XTLB 'currentRatio'
# XYF 'numberOfAnalystOpinions'
# XYF 'overallRisk'
# XYF 'pegRatio'
# XYF 'dividendYield'
# XYF 'fiveYearAvgDividendYield'
# XYF 'freeCashflow'
# YALA 'overallRisk'
# YALA 'beta'
# YALA 'pegRatio'
# YALA 'enterpriseToRevenue'
# YALA 'enterpriseToEbitda'
# YALA 'earningsGrowth'
# YALA 'revenueGrowth'
# YALA 'dividendYield'
# YALA 'fiveYearAvgDividendYield'
# YALA 'freeCashflow'
# YALA 'debtToEquity'
# YALA 'returnOnAssets'
# YALA 'returnOnEquity'
# YALA 'quickRatio'
# YALA 'currentRatio'
# YI 'overallRisk'
# YI 'trailingPE'
# YI 'pegRatio'
# YI 'priceToBook'
# YI 'earningsGrowth'
# YI 'dividendYield'
# YI 'fiveYearAvgDividendYield'
# YJ 'numberOfAnalystOpinions'
# YJ 'overallRisk'
# YJ 'trailingPE'
# YJ 'pegRatio'
# YJ 'earningsGrowth'
# YJ 'dividendYield'
# YJ 'fiveYearAvgDividendYield'
# YJ 'freeCashflow'
# YMM 'overallRisk'
# YMM 'earningsGrowth'
# YMM 'dividendYield'
# YMM 'fiveYearAvgDividendYield'
# YMM 'freeCashflow'
# YPF 'overallRisk'
# YPF 'dividendYield'
# YPF 'fiveYearAvgDividendYield'
# YQ 'numberOfAnalystOpinions'
# YQ 'overallRisk'
# YQ 'trailingPE'
# YQ 'pegRatio'
# YQ 'earningsGrowth'
# YQ 'dividendYield'
# YQ 'fiveYearAvgDividendYield'
# YQ 'freeCashflow'
# YRD 'numberOfAnalystOpinions'
# YRD 'overallRisk'
# YRD 'pegRatio'
# YRD 'dividendYield'
# YRD 'fiveYearAvgDividendYield'
# YRD 'freeCashflow'
# YRD 'returnOnAssets'
# YSG 'overallRisk'
# YSG 'trailingPE'
# YSG 'pegRatio'
# YSG 'earningsGrowth'
# YSG 'dividendYield'
# YSG 'fiveYearAvgDividendYield'
# YSG 'freeCashflow'
# YY 'overallRisk'
# YY 'earningsGrowth'
# YY 'fiveYearAvgDividendYield'
# YY 'freeCashflow'
# ZEAL 'shortName'
# ZEAL 'sector'
# ZEAL 'industry'
# ZEAL 'recommendationMean'
# ZEAL 'numberOfAnalystOpinions'
# ZEAL 'overallRisk'
# ZEAL 'beta'
# ZEAL 'previousClose'
# ZEAL 'trailingEps'
# ZEAL 'forwardEps'
# ZEAL 'trailingPE'
# ZEAL 'forwardPE'
# ZEAL 'pegRatio'
# ZEAL 'bookValue'
# ZEAL 'priceToBook'
# ZEAL 'enterpriseToRevenue'
# ZEAL 'enterpriseToEbitda'
# ZEAL 'ebitdaMargins'
# ZEAL 'profitMargins'
# ZEAL 'earningsGrowth'
# ZEAL 'revenueGrowth'
# ZEAL 'dividendYield'
# ZEAL 'payoutRatio'
# ZEAL 'fiveYearAvgDividendYield'
# ZEAL 'enterpriseValue'
# ZEAL 'freeCashflow'
# ZEAL 'debtToEquity'
# ZEAL 'returnOnAssets'
# ZEAL 'returnOnEquity'
# ZEAL 'quickRatio'
# ZEAL 'currentRatio'
# ZEPP 'overallRisk'
# ZEPP 'trailingPE'
# ZEPP 'earningsGrowth'
# ZEPP 'dividendYield'
# ZEPP 'fiveYearAvgDividendYield'
# ZEPP 'freeCashflow'
# ZH 'overallRisk'
# ZH 'trailingPE'
# ZH 'pegRatio'
# ZH 'earningsGrowth'
# ZH 'dividendYield'
# ZH 'fiveYearAvgDividendYield'
# ZH 'freeCashflow'
# ZLAB 'overallRisk'
# ZLAB 'trailingPE'
# ZLAB 'earningsGrowth'
# ZLAB 'dividendYield'
# ZLAB 'fiveYearAvgDividendYield'
# ZME 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ZME?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ZNH 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/ZNH?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true
# ZTO 'overallRisk'
# ZTO 'dividendYield'
# ZTO 'fiveYearAvgDividendYield'
#                       shortName                  sector  \
# AACG      ATA Creativity Global      Consumer Defensive
# ABB                         NaN                     NaN
# ABCM                  Abcam plc              Healthcare
# ABEV                 Ambev S.A.      Consumer Defensive
# ACH                         NaN                     NaN
# ...                         ...                     ...
# ZH                   Zhihu Inc.  Communication Services
# ZLAB            Zai Lab Limited              Healthcare
# ZME                         NaN                     NaN
# ZNH                         NaN                     NaN
# ZTO   ZTO Express (Cayman) Inc.             Industrials
#
#                             industry recommendationMean  \
# AACG   Education & Training Services                2.0
# ABB                              NaN                NaN
# ABCM                   Biotechnology                2.0
# ABEV               Beverages—Brewers                2.2
# ACH                              NaN                NaN
# ...                              ...                ...
# ZH    Internet Content & Information                2.0
# ZLAB                   Biotechnology                1.7
# ZME                              NaN                NaN
# ZNH                              NaN                NaN
# ZTO   Integrated Freight & Logistics                1.5
#
#      numberOfAnalystOpinions overallRisk      beta previousClose trailingEps  \
# AACG                       1         NaN  1.279503          1.21       -0.22
# ABB                      NaN         NaN       NaN           NaN         NaN
# ABCM                       5         NaN  0.923542         21.54       -0.05
# ABEV                       7           5  0.617467          2.84        0.19
# ACH                      NaN         NaN       NaN           NaN         NaN
# ...                      ...         ...       ...           ...         ...
# ZH                        10         NaN  0.418161           1.1       -0.27
# ZLAB                      12         NaN  1.087287         24.14       -4.32
# ZME                      NaN         NaN       NaN           NaN         NaN
# ZNH                      NaN         NaN       NaN           NaN         NaN
# ZTO                       22         NaN  0.023207         25.29        1.31
#
#      forwardEps  ... dividendYield payoutRatio fiveYearAvgDividendYield  \
# AACG      -0.99  ...           NaN         0.0                      NaN
# ABB         NaN  ...           NaN         NaN                      NaN
# ABCM        NaN  ...           NaN         0.0                      NaN
# ABEV       0.19  ...        0.0508      0.8492                      3.3
# ACH         NaN  ...           NaN         NaN                      NaN
# ...         ...  ...           ...         ...                      ...
# ZH        -0.07  ...           NaN         0.0                      NaN
# ZLAB      -2.98  ...           NaN         0.0                      NaN
# ZME         NaN  ...           NaN         NaN                      NaN
# ZNH         NaN  ...           NaN         NaN                      NaN
# ZTO         1.8  ...           NaN         0.0                      NaN
#
#      enterpriseValue freeCashflow debtToEquity returnOnAssets returnOnEquity  \
# AACG        14553503          NaN       30.286       -0.07129         -0.341
# ABB              NaN          NaN          NaN            NaN            NaN
# ABCM      5068363264     31137500       30.802        0.03268       -0.01229
# ABEV     37677678592  10596658176        4.743        0.08271        0.16919
# ACH              NaN          NaN          NaN            NaN            NaN
# ...              ...          ...          ...            ...            ...
# ZH       -5439845888          NaN        1.704       -0.09152       -0.19223
# ZLAB      1545148032   -272515264        2.044       -0.19548       -0.36652
# ZME              NaN          NaN          NaN            NaN            NaN
# ZNH              NaN          NaN          NaN            NaN            NaN
# ZTO      16920855552   2769136128       26.083        0.07336        0.14513
#
#      quickRatio currentRatio
# AACG      0.175        0.205
# ABB         NaN          NaN
# ABCM      0.889        1.266
# ABEV      0.607        1.006
# ACH         NaN          NaN
# ...         ...          ...
# ZH        3.624        3.735
# ZLAB      7.069         7.63
# ZME         NaN          NaN
# ZNH         NaN          NaN
# ZTO       1.004        1.324
#
# [463 rows x 31 columns]

# %%
features.to_csv(FEATURES_FILE, index=True, index_label='ticker')

# %% [markdown]
# ## Labels
#
# Collect label data from:
#
# - https://www.bestquants.com/2019/11/how-to-web-scrapping-zacks-strong-buy.html
#
# Consider using, to retry requests if necessary:
#
# - https://urllib3.readthedocs.io/en/latest/reference/urllib3.util.html#urllib3.util.Retry

# %%
import requests
from requests.exceptions import HTTPError

def zacks(ticker: str):
    json = { ticker:  None }    
    try:
        response = requests.get('https://quote-feed.zacks.com/index?t=' + ticker)
        response.raise_for_status()
        json = response.json()

    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'Other error occurred: {err}')

    return json

# %%
zacks('MSFT')
# Out:
# {'MSFT': {'source': {'sungard': {'bidasksize': '100x100',
#     'dividend_freq': '4',
#     'prev_close_date': '08/17/2023 11:01:04',
#     'zacks_recommendation': '',
#     'timestamp': '15:59',
#     'exchange': 'NASDAQ',
#     'shares': '',
#     'volatility': '.9',
#     'pos_size': '100',
#     'open': '320.54',
#     'yrlow': '213.431',
#     'type': 'S',
#     'yield': '.85',
#     'market_cap': '2372026365886',
#     'ask': '319.28',
#     'dividend': '.68',
#     'dividend_date': '09/14/2023 00:00:00',
#     'earnings': '9.81',
#     'close': '320.4',
#     'day_low': '318.7001',
#     'last_trade_datetime': '08/17/2023 11:01:04',
#     'volume': '20698864',
#     'yrhigh': '366.78',
#     'day_high': '321.87',
#     'bid': '319.25',
#     'name': 'Microsoft Corporation',
#     'pe_ratio': '29.39',
#     'updated': '08/17/2023 11:01:04'},
#    'bats': {'ask_size': '2',
#     'routed': '19063',
#     'last_trade_datetime': '08/17/2023 11:18:01',
#     'matched': '212784',
#     'bid_size': '50',
#     'net_pct_change': 'NULL',
#     'updated': '08/17/2023 11:18:05',
#     'end_mkt_day_price': 'NULL',
#     'ask_price': '319.03',
#     'bid_price': '318.93',
#     'last': '85.87',
#     'pre_after_updated': '',
#     'net_price_change': 'NULL',
#     'pre_after_price': '',
#     'net_change': 'NULL'},
#    'pre': {'after_percent_net_change': '.04',
#     'after_net_change': '12/19/2017 19:58:07'}},
#   'exchange': 'Real Time Quote from BATS',
#   'dividend_yield': '.85',
#   'last': '319.04',
#   'ticker': 'MSFT',
#   'ticker_type': 'S',
#   'zacks_rank_text': 'Hold',
#   'volume': '5122970',
#   'updated': 'Aug 17, 2023 11:18 AM',
#   'percent_net_change': '-.424',
#   'zacks_rank': '3',
#   'name': 'Microsoft Corporation',
#   'net_change': '-1.36',
#   'market_time': '',
#   'previous_close': '320.4',
#   'SUNGARD_BID': '48.49',
#   'SUNGARD_YRLOW': '34.63',
#   'SUNGARD_PE_RATIO': '2.55',
#   'SUNGARD_DAY_LOW': '2.56',
#   'SUNGARD_MARKET_CAP': '48.345',
#   'FEED_NET_CHANGE': '26-SEP-2014',
#   'BATS_PRE_AFTER_UPDATED': '02-DEC-2014',
#   'SUNGARD_EARNINGS': '.31',
#   'SUNGARD_VOLATILITY': '11-DEC-2014',
#   'SUNGARD_PREV_CLOSE_DATE': '49.05',
#   'BATS_ASK_PRICE': '669597',
#   'SUNGARD_YRHIGH': '50.05',
#   'SUNGARD_DIVIDEND_FREQ': '000',
#   'SUNGARD_VOLUME': '',
#   'SUNGARD_BIDASKSIZE': '45x19',
#   'SUNGARD_YIELD': 'Q',
#   'SUNGARD_DAY_HIGH': '.82',
#   'SUNGARD_ZACKS_RECOMMENDATION': 'S',
#   'SUNGARD_NAME': 'MICROSOFT CP',
#   'SUNGARD_TIMESTAMP': '11:50',
#   'SUNGARD_DIVIDEND_DATE': '853',
#   'BATS_BID_SIZE': '11206',
#   'BATS_BID_PRICE': '1900',
#   'BATS_LAST_TRADE_DATETIME': '46.25',
#   'FEED_VOLUME': '26-SEP-2014',
#   'SUNGARD_SHARES': '8',
#   'SUNGARD_DIVIDEND': '242',
#   'SUNGARD_EXCHANGE': 'NASD',
#   'SUNGARD_TYPE': '19.02',
#   'SUNGARD_LAST_TRADE_DATETIME': '02-DEC-2014',
#   'SUNGARD_UPDATED': '400767.53',
#   'BATS_ROUTED': '02-DEC-2014',
#   'BATS_ASK_SIZE': '02-DEC-2014',
#   'FEED_TICKER': 'MSFT',
#   'SUNGARD_POS_SIZE': '50',
#   'FEED_PERCENT_NET_CHANGE': '48.48',
#   'FEED_SOURCE': '-.14',
#   'BATS_PRE_AFTER_PRICE': '-.288',
#   'BATS_UPDATED': '2700',
#   'FEED_LAST': '46.24',
#   'SUNGARD_ASK': '48.5',
#   'BATS_MATCHED': '',
#   'FEED_UPDATED': '10479795',
#   'SUNGARD_OPEN': '48.84',
#   'SUNGARD_CLOSE': '48.62',
#   'pre_after_net_change': '',
#   'pre_after_percent_net_change': '',
#   'company_short_name': 'Microsoft',
#   'ticker_market_status': 'OPEN PRICES',
#   'ap_short_name': 'Microsoft',
#   'company_logo_url': 'https://staticx-tuner.zacks.com/images/stocks-thumb/MSFT.png',
#   'confirmed_reporting_date': '',
#   'pe_f1': '29.39',
#   'expected_reporting_date': '1698105600',
#   'market_status': 'Full Trading Day (Market Open)',
#   'previous_close_date': '08/16/2023'}}

# %%
labels = pd.DataFrame(index = t, columns=['zacks_rank'])
for idx in labels.index:
    z = zacks(idx)
    try:
        labels.loc[idx, ['zacks_rank']] = z[idx]['zacks_rank']
    except Exception as e:
        print (idx, e)
labels
# Out:
# AMOV 'zacks_rank'
# AMYT 'zacks_rank'
# ANPC 'zacks_rank'
# BLCT 'zacks_rank'
# CIG.C 'zacks_rank'
# CIH 'zacks_rank'
# DIDI 'zacks_rank'
# FHS 'zacks_rank'
# GET 'zacks_rank'
# GSK# 'GSK#'
# HLN# 'HLN#'
# IONR 'zacks_rank'
# MITC 'zacks_rank'
# MOHO 'zacks_rank'
# NWG# 'NWG#'
# OG 'zacks_rank'
# QK 'zacks_rank'
# Symbol 'Symbol'
#      zacks_rank
# AACG
# ABB           3
# ABCM          2
# ABEV          2
# ACH
# ...         ...
# ZH            3
# ZLAB          3
# ZME
# ZNH
# ZTO           2
#
# [463 rows x 1 columns]

# %%
labels.to_csv(LABELS_FILE, index=True, index_label='ticker')
